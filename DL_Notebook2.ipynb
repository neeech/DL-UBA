# %% [markdown]
# Alumnos: Bruno Russo LU 1172/21, Manuel Graña LU 343/21, Joaquín Machulsky LU 521/21, Ignacio Rodríguez Sañudo LU 956/21.

# %% [markdown]
# # Práctica 2: Introducción a PyTorch
#
# ## a) Calculando el gradiente mediante Autograd
#
# En primer lugar, vamos a calcular del gradiente para el perceptrón simple con función de activación sigmoidea que vimos en la teoría. Pero esta vez, en lugar de realizar manualmente el proceso de backpropagation, vamos a usar el módulo `autograd` de PyTorch.
#
# La función $f(x, w)$ a la cual queremos encontrarle el gradiente es:
#
# > $f(\mathbf{x}, \mathbf{w}) = \frac{1}{1 + e^{2-(w_0 x_0 + w_1 x_1 + w_2)}}$
#
# Definimos entonces la función utilizando `torch.tensor` (recordar usar el parámetro `requires_grad = True` para que PyTorch guarde los gradientes) y realizamos la pasada "forward" para los siguientes valores de x y w:
#
# > $\mathbf{x} = (-1, -2)$
#
# > $\mathbf{w} = (2, -3, -3)$

# %%
import numpy as np
import torch

# %%
x = torch.tensor([-1.,-2], requires_grad=True)
w = torch.tensor([2.,-3,-3], requires_grad=True)
f = 1/(1+np.e**(2-(x[0]*w[0]+x[1]*w[1]+w[2])))

print(f)
# Out:
# tensor(0.2689, grad_fn=<MulBackward0>)

# %% [markdown]
# Ahora, utilizando la función `f.backward()` computamos los gradientes $\frac{\partial f}{ \partial \mathbf{x}}$ y $\frac{\partial f}{ \partial \mathbf{w}}$

# %%
f.backward()

# %%
print("Gradiente df/dx = " + str(x.grad))
print("Gradiente df/dw = " + str(w.grad ))
# Out:
# Gradiente df/dx = tensor([ 0.3932, -0.5898])
# Gradiente df/dw = tensor([-0.1966, -0.3932,  0.1966])

# %% [markdown]
# ## b) Minimizando una función con Gradient Descent
#
# Ahora, vamos a implementar usar el algorítmo de gradiente descendiente (utilizando Autograd para computar el gradiente) para minimizar la función cuadrática $$f(x) = 2x^2 + x + 4$$
#
# Utilizaremos la implementación `torch.optim.SGD` de gradiente descendiente.

# %%
import matplotlib.pyplot as plt

# Definir la variable que será el parámetro a optimizar
x = torch.tensor(1., requires_grad=True)

# Definir el optimizador, indicando el parámetro a optimizar y el learning rate
optimizer = torch.optim.SGD([x], lr = 0.001)

# Acumuladores que usaremos para guardar los valores sucesivos de x, y
f_values = []
x_values = []

# Loop de optimización
for i in range(1000):

    # Setemos en 0 los gradientes de todos los elementos
    optimizer.zero_grad()

    # Pasada forward: ejecutar la función a minimizar
    f = 2 * x**2 + x + 4

    print("X = " + str(x) + ", f(x) = " + str(f))

    # Pasada backward: computar los gradientes
    f.backward()
    # Actualizar los pesos dando un paso de gradiente descendiente
    optimizer.step()
    # Guardar los valores para luego plotearlos
    f_values.append(f.data.item())
    x_values.append(x.data.item())

# Ploteo los valores
plt.title("Optimizando la función f = 2 * x**2 + x + 4")
plt.xlabel("X")
plt.plot(x_values,f_values)
# Out:
# X = tensor(1., requires_grad=True), f(x) = tensor(7., grad_fn=<AddBackward0>)
# X = tensor(0.9950, requires_grad=True), f(x) = tensor(6.9750, grad_fn=<AddBackward0>)
# X = tensor(0.9900, requires_grad=True), f(x) = tensor(6.9503, grad_fn=<AddBackward0>)
# X = tensor(0.9851, requires_grad=True), f(x) = tensor(6.9257, grad_fn=<AddBackward0>)
# X = tensor(0.9801, requires_grad=True), f(x) = tensor(6.9014, grad_fn=<AddBackward0>)
# X = tensor(0.9752, requires_grad=True), f(x) = tensor(6.8772, grad_fn=<AddBackward0>)
# X = tensor(0.9703, requires_grad=True), f(x) = tensor(6.8533, grad_fn=<AddBackward0>)
# X = tensor(0.9654, requires_grad=True), f(x) = tensor(6.8295, grad_fn=<AddBackward0>)
# X = tensor(0.9606, requires_grad=True), f(x) = tensor(6.8059, grad_fn=<AddBackward0>)
# X = tensor(0.9557, requires_grad=True), f(x) = tensor(6.7825, grad_fn=<AddBackward0>)
# X = tensor(0.9509, requires_grad=True), f(x) = tensor(6.7593, grad_fn=<AddBackward0>)
# X = tensor(0.9461, requires_grad=True), f(x) = tensor(6.7362, grad_fn=<AddBackward0>)
# X = tensor(0.9413, requires_grad=True), f(x) = tensor(6.7134, grad_fn=<AddBackward0>)
# X = tensor(0.9365, requires_grad=True), f(x) = tensor(6.6907, grad_fn=<AddBackward0>)
# X = tensor(0.9318, requires_grad=True), f(x) = tensor(6.6683, grad_fn=<AddBackward0>)
# X = tensor(0.9271, requires_grad=True), f(x) = tensor(6.6460, grad_fn=<AddBackward0>)
# X = tensor(0.9224, requires_grad=True), f(x) = tensor(6.6238, grad_fn=<AddBackward0>)
# X = tensor(0.9177, requires_grad=True), f(x) = tensor(6.6019, grad_fn=<AddBackward0>)
# X = tensor(0.9130, requires_grad=True), f(x) = tensor(6.5801, grad_fn=<AddBackward0>)
# X = tensor(0.9083, requires_grad=True), f(x) = tensor(6.5585, grad_fn=<AddBackward0>)
# X = tensor(0.9037, requires_grad=True), f(x) = tensor(6.5371, grad_fn=<AddBackward0>)
# X = tensor(0.8991, requires_grad=True), f(x) = tensor(6.5158, grad_fn=<AddBackward0>)
# X = tensor(0.8945, requires_grad=True), f(x) = tensor(6.4948, grad_fn=<AddBackward0>)
# X = tensor(0.8899, requires_grad=True), f(x) = tensor(6.4738, grad_fn=<AddBackward0>)
# X = tensor(0.8854, requires_grad=True), f(x) = tensor(6.4531, grad_fn=<AddBackward0>)
# X = tensor(0.8808, requires_grad=True), f(x) = tensor(6.4325, grad_fn=<AddBackward0>)
# X = tensor(0.8763, requires_grad=True), f(x) = tensor(6.4121, grad_fn=<AddBackward0>)
# X = tensor(0.8718, requires_grad=True), f(x) = tensor(6.3918, grad_fn=<AddBackward0>)
# X = tensor(0.8673, requires_grad=True), f(x) = tensor(6.3717, grad_fn=<AddBackward0>)
# X = tensor(0.8628, requires_grad=True), f(x) = tensor(6.3518, grad_fn=<AddBackward0>)
# X = tensor(0.8584, requires_grad=True), f(x) = tensor(6.3320, grad_fn=<AddBackward0>)
# X = tensor(0.8540, requires_grad=True), f(x) = tensor(6.3124, grad_fn=<AddBackward0>)
# X = tensor(0.8495, requires_grad=True), f(x) = tensor(6.2930, grad_fn=<AddBackward0>)
# X = tensor(0.8451, requires_grad=True), f(x) = tensor(6.2736, grad_fn=<AddBackward0>)
# X = tensor(0.8408, requires_grad=True), f(x) = tensor(6.2545, grad_fn=<AddBackward0>)
# X = tensor(0.8364, requires_grad=True), f(x) = tensor(6.2355, grad_fn=<AddBackward0>)
# X = tensor(0.8320, requires_grad=True), f(x) = tensor(6.2167, grad_fn=<AddBackward0>)
# X = tensor(0.8277, requires_grad=True), f(x) = tensor(6.1980, grad_fn=<AddBackward0>)
# X = tensor(0.8234, requires_grad=True), f(x) = tensor(6.1794, grad_fn=<AddBackward0>)
# X = tensor(0.8191, requires_grad=True), f(x) = tensor(6.1610, grad_fn=<AddBackward0>)
# X = tensor(0.8148, requires_grad=True), f(x) = tensor(6.1428, grad_fn=<AddBackward0>)
# X = tensor(0.8106, requires_grad=True), f(x) = tensor(6.1247, grad_fn=<AddBackward0>)
# X = tensor(0.8063, requires_grad=True), f(x) = tensor(6.1067, grad_fn=<AddBackward0>)
# X = tensor(0.8021, requires_grad=True), f(x) = tensor(6.0889, grad_fn=<AddBackward0>)
# X = tensor(0.7979, requires_grad=True), f(x) = tensor(6.0712, grad_fn=<AddBackward0>)
# X = tensor(0.7937, requires_grad=True), f(x) = tensor(6.0537, grad_fn=<AddBackward0>)
# X = tensor(0.7895, requires_grad=True), f(x) = tensor(6.0363, grad_fn=<AddBackward0>)
# X = tensor(0.7854, requires_grad=True), f(x) = tensor(6.0190, grad_fn=<AddBackward0>)
# X = tensor(0.7812, requires_grad=True), f(x) = tensor(6.0019, grad_fn=<AddBackward0>)
# X = tensor(0.7771, requires_grad=True), f(x) = tensor(5.9849, grad_fn=<AddBackward0>)
# X = tensor(0.7730, requires_grad=True), f(x) = tensor(5.9681, grad_fn=<AddBackward0>)
# X = tensor(0.7689, requires_grad=True), f(x) = tensor(5.9514, grad_fn=<AddBackward0>)
# X = tensor(0.7648, requires_grad=True), f(x) = tensor(5.9348, grad_fn=<AddBackward0>)
# X = tensor(0.7608, requires_grad=True), f(x) = tensor(5.9183, grad_fn=<AddBackward0>)
# X = tensor(0.7567, requires_grad=True), f(x) = tensor(5.9020, grad_fn=<AddBackward0>)
# X = tensor(0.7527, requires_grad=True), f(x) = tensor(5.8858, grad_fn=<AddBackward0>)
# X = tensor(0.7487, requires_grad=True), f(x) = tensor(5.8698, grad_fn=<AddBackward0>)
# X = tensor(0.7447, requires_grad=True), f(x) = tensor(5.8539, grad_fn=<AddBackward0>)
# X = tensor(0.7407, requires_grad=True), f(x) = tensor(5.8381, grad_fn=<AddBackward0>)
# X = tensor(0.7368, requires_grad=True), f(x) = tensor(5.8224, grad_fn=<AddBackward0>)
# X = tensor(0.7328, requires_grad=True), f(x) = tensor(5.8068, grad_fn=<AddBackward0>)
# X = tensor(0.7289, requires_grad=True), f(x) = tensor(5.7914, grad_fn=<AddBackward0>)
# X = tensor(0.7250, requires_grad=True), f(x) = tensor(5.7761, grad_fn=<AddBackward0>)
# X = tensor(0.7211, requires_grad=True), f(x) = tensor(5.7609, grad_fn=<AddBackward0>)
# X = tensor(0.7172, requires_grad=True), f(x) = tensor(5.7459, grad_fn=<AddBackward0>)
# X = tensor(0.7133, requires_grad=True), f(x) = tensor(5.7309, grad_fn=<AddBackward0>)
# X = tensor(0.7095, requires_grad=True), f(x) = tensor(5.7161, grad_fn=<AddBackward0>)
# X = tensor(0.7056, requires_grad=True), f(x) = tensor(5.7014, grad_fn=<AddBackward0>)
# X = tensor(0.7018, requires_grad=True), f(x) = tensor(5.6868, grad_fn=<AddBackward0>)
# X = tensor(0.6980, requires_grad=True), f(x) = tensor(5.6724, grad_fn=<AddBackward0>)
# X = tensor(0.6942, requires_grad=True), f(x) = tensor(5.6580, grad_fn=<AddBackward0>)
# X = tensor(0.6904, requires_grad=True), f(x) = tensor(5.6438, grad_fn=<AddBackward0>)
# X = tensor(0.6867, requires_grad=True), f(x) = tensor(5.6297, grad_fn=<AddBackward0>)
# X = tensor(0.6829, requires_grad=True), f(x) = tensor(5.6157, grad_fn=<AddBackward0>)
# X = tensor(0.6792, requires_grad=True), f(x) = tensor(5.6018, grad_fn=<AddBackward0>)
# X = tensor(0.6755, requires_grad=True), f(x) = tensor(5.5880, grad_fn=<AddBackward0>)
# X = tensor(0.6718, requires_grad=True), f(x) = tensor(5.5743, grad_fn=<AddBackward0>)
# X = tensor(0.6681, requires_grad=True), f(x) = tensor(5.5607, grad_fn=<AddBackward0>)
# X = tensor(0.6644, requires_grad=True), f(x) = tensor(5.5473, grad_fn=<AddBackward0>)
# X = tensor(0.6607, requires_grad=True), f(x) = tensor(5.5339, grad_fn=<AddBackward0>)
# X = tensor(0.6571, requires_grad=True), f(x) = tensor(5.5207, grad_fn=<AddBackward0>)
# X = tensor(0.6535, requires_grad=True), f(x) = tensor(5.5075, grad_fn=<AddBackward0>)
# X = tensor(0.6499, requires_grad=True), f(x) = tensor(5.4945, grad_fn=<AddBackward0>)
# X = tensor(0.6463, requires_grad=True), f(x) = tensor(5.4816, grad_fn=<AddBackward0>)
# X = tensor(0.6427, requires_grad=True), f(x) = tensor(5.4687, grad_fn=<AddBackward0>)
# X = tensor(0.6391, requires_grad=True), f(x) = tensor(5.4560, grad_fn=<AddBackward0>)
# X = tensor(0.6356, requires_grad=True), f(x) = tensor(5.4434, grad_fn=<AddBackward0>)
# X = tensor(0.6320, requires_grad=True), f(x) = tensor(5.4309, grad_fn=<AddBackward0>)
# X = tensor(0.6285, requires_grad=True), f(x) = tensor(5.4185, grad_fn=<AddBackward0>)
# X = tensor(0.6250, requires_grad=True), f(x) = tensor(5.4061, grad_fn=<AddBackward0>)
# X = tensor(0.6215, requires_grad=True), f(x) = tensor(5.3939, grad_fn=<AddBackward0>)
# X = tensor(0.6180, requires_grad=True), f(x) = tensor(5.3818, grad_fn=<AddBackward0>)
# X = tensor(0.6145, requires_grad=True), f(x) = tensor(5.3697, grad_fn=<AddBackward0>)
# X = tensor(0.6111, requires_grad=True), f(x) = tensor(5.3578, grad_fn=<AddBackward0>)
# X = tensor(0.6076, requires_grad=True), f(x) = tensor(5.3460, grad_fn=<AddBackward0>)
# X = tensor(0.6042, requires_grad=True), f(x) = tensor(5.3342, grad_fn=<AddBackward0>)
# X = tensor(0.6008, requires_grad=True), f(x) = tensor(5.3226, grad_fn=<AddBackward0>)
# X = tensor(0.5974, requires_grad=True), f(x) = tensor(5.3110, grad_fn=<AddBackward0>)
# X = tensor(0.5940, requires_grad=True), f(x) = tensor(5.2996, grad_fn=<AddBackward0>)
# X = tensor(0.5906, requires_grad=True), f(x) = tensor(5.2882, grad_fn=<AddBackward0>)
# X = tensor(0.5872, requires_grad=True), f(x) = tensor(5.2769, grad_fn=<AddBackward0>)
# X = tensor(0.5839, requires_grad=True), f(x) = tensor(5.2657, grad_fn=<AddBackward0>)
# X = tensor(0.5805, requires_grad=True), f(x) = tensor(5.2546, grad_fn=<AddBackward0>)
# X = tensor(0.5772, requires_grad=True), f(x) = tensor(5.2436, grad_fn=<AddBackward0>)
# X = tensor(0.5739, requires_grad=True), f(x) = tensor(5.2327, grad_fn=<AddBackward0>)
# X = tensor(0.5706, requires_grad=True), f(x) = tensor(5.2218, grad_fn=<AddBackward0>)
# X = tensor(0.5673, requires_grad=True), f(x) = tensor(5.2111, grad_fn=<AddBackward0>)
# X = tensor(0.5641, requires_grad=True), f(x) = tensor(5.2004, grad_fn=<AddBackward0>)
# X = tensor(0.5608, requires_grad=True), f(x) = tensor(5.1898, grad_fn=<AddBackward0>)
# X = tensor(0.5576, requires_grad=True), f(x) = tensor(5.1793, grad_fn=<AddBackward0>)
# X = tensor(0.5543, requires_grad=True), f(x) = tensor(5.1689, grad_fn=<AddBackward0>)
# X = tensor(0.5511, requires_grad=True), f(x) = tensor(5.1586, grad_fn=<AddBackward0>)
# X = tensor(0.5479, requires_grad=True), f(x) = tensor(5.1483, grad_fn=<AddBackward0>)
# X = tensor(0.5447, requires_grad=True), f(x) = tensor(5.1382, grad_fn=<AddBackward0>)
# X = tensor(0.5415, requires_grad=True), f(x) = tensor(5.1281, grad_fn=<AddBackward0>)
# X = tensor(0.5384, requires_grad=True), f(x) = tensor(5.1181, grad_fn=<AddBackward0>)
# X = tensor(0.5352, requires_grad=True), f(x) = tensor(5.1082, grad_fn=<AddBackward0>)
# X = tensor(0.5321, requires_grad=True), f(x) = tensor(5.0983, grad_fn=<AddBackward0>)
# X = tensor(0.5290, requires_grad=True), f(x) = tensor(5.0885, grad_fn=<AddBackward0>)
# X = tensor(0.5258, requires_grad=True), f(x) = tensor(5.0789, grad_fn=<AddBackward0>)
# X = tensor(0.5227, requires_grad=True), f(x) = tensor(5.0692, grad_fn=<AddBackward0>)
# X = tensor(0.5196, requires_grad=True), f(x) = tensor(5.0597, grad_fn=<AddBackward0>)
# X = tensor(0.5166, requires_grad=True), f(x) = tensor(5.0502, grad_fn=<AddBackward0>)
# X = tensor(0.5135, requires_grad=True), f(x) = tensor(5.0409, grad_fn=<AddBackward0>)
# X = tensor(0.5104, requires_grad=True), f(x) = tensor(5.0316, grad_fn=<AddBackward0>)
# X = tensor(0.5074, requires_grad=True), f(x) = tensor(5.0223, grad_fn=<AddBackward0>)
# X = tensor(0.5044, requires_grad=True), f(x) = tensor(5.0132, grad_fn=<AddBackward0>)
# X = tensor(0.5014, requires_grad=True), f(x) = tensor(5.0041, grad_fn=<AddBackward0>)
# X = tensor(0.4984, requires_grad=True), f(x) = tensor(4.9951, grad_fn=<AddBackward0>)
# X = tensor(0.4954, requires_grad=True), f(x) = tensor(4.9861, grad_fn=<AddBackward0>)
# X = tensor(0.4924, requires_grad=True), f(x) = tensor(4.9772, grad_fn=<AddBackward0>)
# X = tensor(0.4894, requires_grad=True), f(x) = tensor(4.9684, grad_fn=<AddBackward0>)
# X = tensor(0.4864, requires_grad=True), f(x) = tensor(4.9597, grad_fn=<AddBackward0>)
# X = tensor(0.4835, requires_grad=True), f(x) = tensor(4.9511, grad_fn=<AddBackward0>)
# X = tensor(0.4806, requires_grad=True), f(x) = tensor(4.9425, grad_fn=<AddBackward0>)
# X = tensor(0.4776, requires_grad=True), f(x) = tensor(4.9339, grad_fn=<AddBackward0>)
# X = tensor(0.4747, requires_grad=True), f(x) = tensor(4.9255, grad_fn=<AddBackward0>)
# X = tensor(0.4718, requires_grad=True), f(x) = tensor(4.9171, grad_fn=<AddBackward0>)
# X = tensor(0.4690, requires_grad=True), f(x) = tensor(4.9088, grad_fn=<AddBackward0>)
# X = tensor(0.4661, requires_grad=True), f(x) = tensor(4.9005, grad_fn=<AddBackward0>)
# X = tensor(0.4632, requires_grad=True), f(x) = tensor(4.8923, grad_fn=<AddBackward0>)
# X = tensor(0.4604, requires_grad=True), f(x) = tensor(4.8842, grad_fn=<AddBackward0>)
# X = tensor(0.4575, requires_grad=True), f(x) = tensor(4.8762, grad_fn=<AddBackward0>)
# X = tensor(0.4547, requires_grad=True), f(x) = tensor(4.8682, grad_fn=<AddBackward0>)
# X = tensor(0.4519, requires_grad=True), f(x) = tensor(4.8602, grad_fn=<AddBackward0>)
# X = tensor(0.4491, requires_grad=True), f(x) = tensor(4.8524, grad_fn=<AddBackward0>)
# X = tensor(0.4463, requires_grad=True), f(x) = tensor(4.8446, grad_fn=<AddBackward0>)
# X = tensor(0.4435, requires_grad=True), f(x) = tensor(4.8368, grad_fn=<AddBackward0>)
# X = tensor(0.4407, requires_grad=True), f(x) = tensor(4.8291, grad_fn=<AddBackward0>)
# X = tensor(0.4379, requires_grad=True), f(x) = tensor(4.8215, grad_fn=<AddBackward0>)
# X = tensor(0.4352, requires_grad=True), f(x) = tensor(4.8140, grad_fn=<AddBackward0>)
# X = tensor(0.4324, requires_grad=True), f(x) = tensor(4.8065, grad_fn=<AddBackward0>)
# X = tensor(0.4297, requires_grad=True), f(x) = tensor(4.7990, grad_fn=<AddBackward0>)
# X = tensor(0.4270, requires_grad=True), f(x) = tensor(4.7917, grad_fn=<AddBackward0>)
# X = tensor(0.4243, requires_grad=True), f(x) = tensor(4.7843, grad_fn=<AddBackward0>)
# X = tensor(0.4216, requires_grad=True), f(x) = tensor(4.7771, grad_fn=<AddBackward0>)
# X = tensor(0.4189, requires_grad=True), f(x) = tensor(4.7699, grad_fn=<AddBackward0>)
# X = tensor(0.4162, requires_grad=True), f(x) = tensor(4.7627, grad_fn=<AddBackward0>)
# X = tensor(0.4136, requires_grad=True), f(x) = tensor(4.7556, grad_fn=<AddBackward0>)
# X = tensor(0.4109, requires_grad=True), f(x) = tensor(4.7486, grad_fn=<AddBackward0>)
# X = tensor(0.4083, requires_grad=True), f(x) = tensor(4.7416, grad_fn=<AddBackward0>)
# X = tensor(0.4056, requires_grad=True), f(x) = tensor(4.7347, grad_fn=<AddBackward0>)
# X = tensor(0.4030, requires_grad=True), f(x) = tensor(4.7279, grad_fn=<AddBackward0>)
# X = tensor(0.4004, requires_grad=True), f(x) = tensor(4.7210, grad_fn=<AddBackward0>)
# X = tensor(0.3978, requires_grad=True), f(x) = tensor(4.7143, grad_fn=<AddBackward0>)
# X = tensor(0.3952, requires_grad=True), f(x) = tensor(4.7076, grad_fn=<AddBackward0>)
# X = tensor(0.3926, requires_grad=True), f(x) = tensor(4.7009, grad_fn=<AddBackward0>)
# X = tensor(0.3901, requires_grad=True), f(x) = tensor(4.6943, grad_fn=<AddBackward0>)
# X = tensor(0.3875, requires_grad=True), f(x) = tensor(4.6878, grad_fn=<AddBackward0>)
# X = tensor(0.3849, requires_grad=True), f(x) = tensor(4.6813, grad_fn=<AddBackward0>)
# X = tensor(0.3824, requires_grad=True), f(x) = tensor(4.6749, grad_fn=<AddBackward0>)
# X = tensor(0.3799, requires_grad=True), f(x) = tensor(4.6685, grad_fn=<AddBackward0>)
# X = tensor(0.3774, requires_grad=True), f(x) = tensor(4.6622, grad_fn=<AddBackward0>)
# X = tensor(0.3748, requires_grad=True), f(x) = tensor(4.6559, grad_fn=<AddBackward0>)
# X = tensor(0.3724, requires_grad=True), f(x) = tensor(4.6496, grad_fn=<AddBackward0>)
# X = tensor(0.3699, requires_grad=True), f(x) = tensor(4.6435, grad_fn=<AddBackward0>)
# X = tensor(0.3674, requires_grad=True), f(x) = tensor(4.6373, grad_fn=<AddBackward0>)
# X = tensor(0.3649, requires_grad=True), f(x) = tensor(4.6312, grad_fn=<AddBackward0>)
# X = tensor(0.3625, requires_grad=True), f(x) = tensor(4.6252, grad_fn=<AddBackward0>)
# X = tensor(0.3600, requires_grad=True), f(x) = tensor(4.6192, grad_fn=<AddBackward0>)
# X = tensor(0.3576, requires_grad=True), f(x) = tensor(4.6133, grad_fn=<AddBackward0>)
# X = tensor(0.3551, requires_grad=True), f(x) = tensor(4.6074, grad_fn=<AddBackward0>)
# X = tensor(0.3527, requires_grad=True), f(x) = tensor(4.6015, grad_fn=<AddBackward0>)
# X = tensor(0.3503, requires_grad=True), f(x) = tensor(4.5957, grad_fn=<AddBackward0>)
# X = tensor(0.3479, requires_grad=True), f(x) = tensor(4.5900, grad_fn=<AddBackward0>)
# X = tensor(0.3455, requires_grad=True), f(x) = tensor(4.5843, grad_fn=<AddBackward0>)
# X = tensor(0.3431, requires_grad=True), f(x) = tensor(4.5786, grad_fn=<AddBackward0>)
# X = tensor(0.3408, requires_grad=True), f(x) = tensor(4.5730, grad_fn=<AddBackward0>)
# X = tensor(0.3384, requires_grad=True), f(x) = tensor(4.5674, grad_fn=<AddBackward0>)
# X = tensor(0.3360, requires_grad=True), f(x) = tensor(4.5619, grad_fn=<AddBackward0>)
# X = tensor(0.3337, requires_grad=True), f(x) = tensor(4.5564, grad_fn=<AddBackward0>)
# X = tensor(0.3314, requires_grad=True), f(x) = tensor(4.5510, grad_fn=<AddBackward0>)
# X = tensor(0.3290, requires_grad=True), f(x) = tensor(4.5456, grad_fn=<AddBackward0>)
# X = tensor(0.3267, requires_grad=True), f(x) = tensor(4.5402, grad_fn=<AddBackward0>)
# X = tensor(0.3244, requires_grad=True), f(x) = tensor(4.5349, grad_fn=<AddBackward0>)
# X = tensor(0.3221, requires_grad=True), f(x) = tensor(4.5296, grad_fn=<AddBackward0>)
# X = tensor(0.3198, requires_grad=True), f(x) = tensor(4.5244, grad_fn=<AddBackward0>)
# X = tensor(0.3175, requires_grad=True), f(x) = tensor(4.5192, grad_fn=<AddBackward0>)
# X = tensor(0.3153, requires_grad=True), f(x) = tensor(4.5141, grad_fn=<AddBackward0>)
# X = tensor(0.3130, requires_grad=True), f(x) = tensor(4.5090, grad_fn=<AddBackward0>)
# X = tensor(0.3108, requires_grad=True), f(x) = tensor(4.5039, grad_fn=<AddBackward0>)
# X = tensor(0.3085, requires_grad=True), f(x) = tensor(4.4989, grad_fn=<AddBackward0>)
# X = tensor(0.3063, requires_grad=True), f(x) = tensor(4.4939, grad_fn=<AddBackward0>)
# X = tensor(0.3041, requires_grad=True), f(x) = tensor(4.4890, grad_fn=<AddBackward0>)
# X = tensor(0.3018, requires_grad=True), f(x) = tensor(4.4841, grad_fn=<AddBackward0>)
# X = tensor(0.2996, requires_grad=True), f(x) = tensor(4.4792, grad_fn=<AddBackward0>)
# X = tensor(0.2974, requires_grad=True), f(x) = tensor(4.4744, grad_fn=<AddBackward0>)
# X = tensor(0.2952, requires_grad=True), f(x) = tensor(4.4696, grad_fn=<AddBackward0>)
# X = tensor(0.2931, requires_grad=True), f(x) = tensor(4.4648, grad_fn=<AddBackward0>)
# X = tensor(0.2909, requires_grad=True), f(x) = tensor(4.4601, grad_fn=<AddBackward0>)
# X = tensor(0.2887, requires_grad=True), f(x) = tensor(4.4555, grad_fn=<AddBackward0>)
# X = tensor(0.2866, requires_grad=True), f(x) = tensor(4.4508, grad_fn=<AddBackward0>)
# X = tensor(0.2844, requires_grad=True), f(x) = tensor(4.4462, grad_fn=<AddBackward0>)
# X = tensor(0.2823, requires_grad=True), f(x) = tensor(4.4417, grad_fn=<AddBackward0>)
# X = tensor(0.2802, requires_grad=True), f(x) = tensor(4.4371, grad_fn=<AddBackward0>)
# X = tensor(0.2780, requires_grad=True), f(x) = tensor(4.4327, grad_fn=<AddBackward0>)
# X = tensor(0.2759, requires_grad=True), f(x) = tensor(4.4282, grad_fn=<AddBackward0>)
# X = tensor(0.2738, requires_grad=True), f(x) = tensor(4.4238, grad_fn=<AddBackward0>)
# X = tensor(0.2717, requires_grad=True), f(x) = tensor(4.4194, grad_fn=<AddBackward0>)
# X = tensor(0.2696, requires_grad=True), f(x) = tensor(4.4151, grad_fn=<AddBackward0>)
# X = tensor(0.2676, requires_grad=True), f(x) = tensor(4.4107, grad_fn=<AddBackward0>)
# X = tensor(0.2655, requires_grad=True), f(x) = tensor(4.4065, grad_fn=<AddBackward0>)
# X = tensor(0.2634, requires_grad=True), f(x) = tensor(4.4022, grad_fn=<AddBackward0>)
# X = tensor(0.2614, requires_grad=True), f(x) = tensor(4.3980, grad_fn=<AddBackward0>)
# X = tensor(0.2593, requires_grad=True), f(x) = tensor(4.3938, grad_fn=<AddBackward0>)
# X = tensor(0.2573, requires_grad=True), f(x) = tensor(4.3897, grad_fn=<AddBackward0>)
# X = tensor(0.2553, requires_grad=True), f(x) = tensor(4.3856, grad_fn=<AddBackward0>)
# X = tensor(0.2532, requires_grad=True), f(x) = tensor(4.3815, grad_fn=<AddBackward0>)
# X = tensor(0.2512, requires_grad=True), f(x) = tensor(4.3775, grad_fn=<AddBackward0>)
# X = tensor(0.2492, requires_grad=True), f(x) = tensor(4.3735, grad_fn=<AddBackward0>)
# X = tensor(0.2472, requires_grad=True), f(x) = tensor(4.3695, grad_fn=<AddBackward0>)
# X = tensor(0.2452, requires_grad=True), f(x) = tensor(4.3655, grad_fn=<AddBackward0>)
# X = tensor(0.2433, requires_grad=True), f(x) = tensor(4.3616, grad_fn=<AddBackward0>)
# X = tensor(0.2413, requires_grad=True), f(x) = tensor(4.3577, grad_fn=<AddBackward0>)
# X = tensor(0.2393, requires_grad=True), f(x) = tensor(4.3539, grad_fn=<AddBackward0>)
# X = tensor(0.2374, requires_grad=True), f(x) = tensor(4.3500, grad_fn=<AddBackward0>)
# X = tensor(0.2354, requires_grad=True), f(x) = tensor(4.3463, grad_fn=<AddBackward0>)
# X = tensor(0.2335, requires_grad=True), f(x) = tensor(4.3425, grad_fn=<AddBackward0>)
# X = tensor(0.2315, requires_grad=True), f(x) = tensor(4.3388, grad_fn=<AddBackward0>)
# X = tensor(0.2296, requires_grad=True), f(x) = tensor(4.3351, grad_fn=<AddBackward0>)
# X = tensor(0.2277, requires_grad=True), f(x) = tensor(4.3314, grad_fn=<AddBackward0>)
# X = tensor(0.2258, requires_grad=True), f(x) = tensor(4.3277, grad_fn=<AddBackward0>)
# X = tensor(0.2239, requires_grad=True), f(x) = tensor(4.3241, grad_fn=<AddBackward0>)
# X = tensor(0.2220, requires_grad=True), f(x) = tensor(4.3205, grad_fn=<AddBackward0>)
# X = tensor(0.2201, requires_grad=True), f(x) = tensor(4.3170, grad_fn=<AddBackward0>)
# X = tensor(0.2182, requires_grad=True), f(x) = tensor(4.3135, grad_fn=<AddBackward0>)
# X = tensor(0.2163, requires_grad=True), f(x) = tensor(4.3100, grad_fn=<AddBackward0>)
# X = tensor(0.2145, requires_grad=True), f(x) = tensor(4.3065, grad_fn=<AddBackward0>)
# X = tensor(0.2126, requires_grad=True), f(x) = tensor(4.3030, grad_fn=<AddBackward0>)
# X = tensor(0.2108, requires_grad=True), f(x) = tensor(4.2996, grad_fn=<AddBackward0>)
# X = tensor(0.2089, requires_grad=True), f(x) = tensor(4.2962, grad_fn=<AddBackward0>)
# X = tensor(0.2071, requires_grad=True), f(x) = tensor(4.2929, grad_fn=<AddBackward0>)
# X = tensor(0.2053, requires_grad=True), f(x) = tensor(4.2895, grad_fn=<AddBackward0>)
# X = tensor(0.2034, requires_grad=True), f(x) = tensor(4.2862, grad_fn=<AddBackward0>)
# X = tensor(0.2016, requires_grad=True), f(x) = tensor(4.2829, grad_fn=<AddBackward0>)
# X = tensor(0.1998, requires_grad=True), f(x) = tensor(4.2797, grad_fn=<AddBackward0>)
# X = tensor(0.1980, requires_grad=True), f(x) = tensor(4.2765, grad_fn=<AddBackward0>)
# X = tensor(0.1962, requires_grad=True), f(x) = tensor(4.2732, grad_fn=<AddBackward0>)
# X = tensor(0.1944, requires_grad=True), f(x) = tensor(4.2701, grad_fn=<AddBackward0>)
# X = tensor(0.1927, requires_grad=True), f(x) = tensor(4.2669, grad_fn=<AddBackward0>)
# X = tensor(0.1909, requires_grad=True), f(x) = tensor(4.2638, grad_fn=<AddBackward0>)
# X = tensor(0.1891, requires_grad=True), f(x) = tensor(4.2607, grad_fn=<AddBackward0>)
# X = tensor(0.1874, requires_grad=True), f(x) = tensor(4.2576, grad_fn=<AddBackward0>)
# X = tensor(0.1856, requires_grad=True), f(x) = tensor(4.2545, grad_fn=<AddBackward0>)
# X = tensor(0.1839, requires_grad=True), f(x) = tensor(4.2515, grad_fn=<AddBackward0>)
# X = tensor(0.1822, requires_grad=True), f(x) = tensor(4.2485, grad_fn=<AddBackward0>)
# X = tensor(0.1804, requires_grad=True), f(x) = tensor(4.2455, grad_fn=<AddBackward0>)
# X = tensor(0.1787, requires_grad=True), f(x) = tensor(4.2426, grad_fn=<AddBackward0>)
# X = tensor(0.1770, requires_grad=True), f(x) = tensor(4.2396, grad_fn=<AddBackward0>)
# X = tensor(0.1753, requires_grad=True), f(x) = tensor(4.2367, grad_fn=<AddBackward0>)
# X = tensor(0.1736, requires_grad=True), f(x) = tensor(4.2338, grad_fn=<AddBackward0>)
# X = tensor(0.1719, requires_grad=True), f(x) = tensor(4.2310, grad_fn=<AddBackward0>)
# X = tensor(0.1702, requires_grad=True), f(x) = tensor(4.2281, grad_fn=<AddBackward0>)
# X = tensor(0.1685, requires_grad=True), f(x) = tensor(4.2253, grad_fn=<AddBackward0>)
# X = tensor(0.1668, requires_grad=True), f(x) = tensor(4.2225, grad_fn=<AddBackward0>)
# X = tensor(0.1652, requires_grad=True), f(x) = tensor(4.2197, grad_fn=<AddBackward0>)
# X = tensor(0.1635, requires_grad=True), f(x) = tensor(4.2170, grad_fn=<AddBackward0>)
# X = tensor(0.1619, requires_grad=True), f(x) = tensor(4.2143, grad_fn=<AddBackward0>)
# X = tensor(0.1602, requires_grad=True), f(x) = tensor(4.2115, grad_fn=<AddBackward0>)
# X = tensor(0.1586, requires_grad=True), f(x) = tensor(4.2089, grad_fn=<AddBackward0>)
# X = tensor(0.1569, requires_grad=True), f(x) = tensor(4.2062, grad_fn=<AddBackward0>)
# X = tensor(0.1553, requires_grad=True), f(x) = tensor(4.2035, grad_fn=<AddBackward0>)
# X = tensor(0.1537, requires_grad=True), f(x) = tensor(4.2009, grad_fn=<AddBackward0>)
# X = tensor(0.1521, requires_grad=True), f(x) = tensor(4.1983, grad_fn=<AddBackward0>)
# X = tensor(0.1505, requires_grad=True), f(x) = tensor(4.1957, grad_fn=<AddBackward0>)
# X = tensor(0.1489, requires_grad=True), f(x) = tensor(4.1932, grad_fn=<AddBackward0>)
# X = tensor(0.1473, requires_grad=True), f(x) = tensor(4.1906, grad_fn=<AddBackward0>)
# X = tensor(0.1457, requires_grad=True), f(x) = tensor(4.1881, grad_fn=<AddBackward0>)
# X = tensor(0.1441, requires_grad=True), f(x) = tensor(4.1856, grad_fn=<AddBackward0>)
# X = tensor(0.1425, requires_grad=True), f(x) = tensor(4.1831, grad_fn=<AddBackward0>)
# X = tensor(0.1409, requires_grad=True), f(x) = tensor(4.1807, grad_fn=<AddBackward0>)
# X = tensor(0.1394, requires_grad=True), f(x) = tensor(4.1782, grad_fn=<AddBackward0>)
# X = tensor(0.1378, requires_grad=True), f(x) = tensor(4.1758, grad_fn=<AddBackward0>)
# X = tensor(0.1363, requires_grad=True), f(x) = tensor(4.1734, grad_fn=<AddBackward0>)
# X = tensor(0.1347, requires_grad=True), f(x) = tensor(4.1710, grad_fn=<AddBackward0>)
# X = tensor(0.1332, requires_grad=True), f(x) = tensor(4.1687, grad_fn=<AddBackward0>)
# X = tensor(0.1317, requires_grad=True), f(x) = tensor(4.1663, grad_fn=<AddBackward0>)
# X = tensor(0.1301, requires_grad=True), f(x) = tensor(4.1640, grad_fn=<AddBackward0>)
# X = tensor(0.1286, requires_grad=True), f(x) = tensor(4.1617, grad_fn=<AddBackward0>)
# X = tensor(0.1271, requires_grad=True), f(x) = tensor(4.1594, grad_fn=<AddBackward0>)
# X = tensor(0.1256, requires_grad=True), f(x) = tensor(4.1571, grad_fn=<AddBackward0>)
# X = tensor(0.1241, requires_grad=True), f(x) = tensor(4.1549, grad_fn=<AddBackward0>)
# X = tensor(0.1226, requires_grad=True), f(x) = tensor(4.1526, grad_fn=<AddBackward0>)
# X = tensor(0.1211, requires_grad=True), f(x) = tensor(4.1504, grad_fn=<AddBackward0>)
# X = tensor(0.1196, requires_grad=True), f(x) = tensor(4.1482, grad_fn=<AddBackward0>)
# X = tensor(0.1181, requires_grad=True), f(x) = tensor(4.1460, grad_fn=<AddBackward0>)
# X = tensor(0.1167, requires_grad=True), f(x) = tensor(4.1439, grad_fn=<AddBackward0>)
# X = tensor(0.1152, requires_grad=True), f(x) = tensor(4.1417, grad_fn=<AddBackward0>)
# X = tensor(0.1137, requires_grad=True), f(x) = tensor(4.1396, grad_fn=<AddBackward0>)
# X = tensor(0.1123, requires_grad=True), f(x) = tensor(4.1375, grad_fn=<AddBackward0>)
# X = tensor(0.1108, requires_grad=True), f(x) = tensor(4.1354, grad_fn=<AddBackward0>)
# X = tensor(0.1094, requires_grad=True), f(x) = tensor(4.1333, grad_fn=<AddBackward0>)
# X = tensor(0.1080, requires_grad=True), f(x) = tensor(4.1313, grad_fn=<AddBackward0>)
# X = tensor(0.1065, requires_grad=True), f(x) = tensor(4.1292, grad_fn=<AddBackward0>)
# X = tensor(0.1051, requires_grad=True), f(x) = tensor(4.1272, grad_fn=<AddBackward0>)
# X = tensor(0.1037, requires_grad=True), f(x) = tensor(4.1252, grad_fn=<AddBackward0>)
# X = tensor(0.1023, requires_grad=True), f(x) = tensor(4.1232, grad_fn=<AddBackward0>)
# X = tensor(0.1008, requires_grad=True), f(x) = tensor(4.1212, grad_fn=<AddBackward0>)
# X = tensor(0.0994, requires_grad=True), f(x) = tensor(4.1192, grad_fn=<AddBackward0>)
# X = tensor(0.0980, requires_grad=True), f(x) = tensor(4.1173, grad_fn=<AddBackward0>)
# X = tensor(0.0967, requires_grad=True), f(x) = tensor(4.1153, grad_fn=<AddBackward0>)
# X = tensor(0.0953, requires_grad=True), f(x) = tensor(4.1134, grad_fn=<AddBackward0>)
# X = tensor(0.0939, requires_grad=True), f(x) = tensor(4.1115, grad_fn=<AddBackward0>)
# X = tensor(0.0925, requires_grad=True), f(x) = tensor(4.1096, grad_fn=<AddBackward0>)
# X = tensor(0.0911, requires_grad=True), f(x) = tensor(4.1078, grad_fn=<AddBackward0>)
# X = tensor(0.0898, requires_grad=True), f(x) = tensor(4.1059, grad_fn=<AddBackward0>)
# X = tensor(0.0884, requires_grad=True), f(x) = tensor(4.1041, grad_fn=<AddBackward0>)
# X = tensor(0.0871, requires_grad=True), f(x) = tensor(4.1022, grad_fn=<AddBackward0>)
# X = tensor(0.0857, requires_grad=True), f(x) = tensor(4.1004, grad_fn=<AddBackward0>)
# X = tensor(0.0844, requires_grad=True), f(x) = tensor(4.0986, grad_fn=<AddBackward0>)
# X = tensor(0.0830, requires_grad=True), f(x) = tensor(4.0968, grad_fn=<AddBackward0>)
# X = tensor(0.0817, requires_grad=True), f(x) = tensor(4.0951, grad_fn=<AddBackward0>)
# X = tensor(0.0804, requires_grad=True), f(x) = tensor(4.0933, grad_fn=<AddBackward0>)
# X = tensor(0.0791, requires_grad=True), f(x) = tensor(4.0916, grad_fn=<AddBackward0>)
# X = tensor(0.0777, requires_grad=True), f(x) = tensor(4.0898, grad_fn=<AddBackward0>)
# X = tensor(0.0764, requires_grad=True), f(x) = tensor(4.0881, grad_fn=<AddBackward0>)
# X = tensor(0.0751, requires_grad=True), f(x) = tensor(4.0864, grad_fn=<AddBackward0>)
# X = tensor(0.0738, requires_grad=True), f(x) = tensor(4.0847, grad_fn=<AddBackward0>)
# X = tensor(0.0725, requires_grad=True), f(x) = tensor(4.0830, grad_fn=<AddBackward0>)
# X = tensor(0.0712, requires_grad=True), f(x) = tensor(4.0814, grad_fn=<AddBackward0>)
# X = tensor(0.0700, requires_grad=True), f(x) = tensor(4.0797, grad_fn=<AddBackward0>)
# X = tensor(0.0687, requires_grad=True), f(x) = tensor(4.0781, grad_fn=<AddBackward0>)
# X = tensor(0.0674, requires_grad=True), f(x) = tensor(4.0765, grad_fn=<AddBackward0>)
# X = tensor(0.0661, requires_grad=True), f(x) = tensor(4.0749, grad_fn=<AddBackward0>)
# X = tensor(0.0649, requires_grad=True), f(x) = tensor(4.0733, grad_fn=<AddBackward0>)
# X = tensor(0.0636, requires_grad=True), f(x) = tensor(4.0717, grad_fn=<AddBackward0>)
# X = tensor(0.0623, requires_grad=True), f(x) = tensor(4.0701, grad_fn=<AddBackward0>)
# X = tensor(0.0611, requires_grad=True), f(x) = tensor(4.0686, grad_fn=<AddBackward0>)
# X = tensor(0.0599, requires_grad=True), f(x) = tensor(4.0670, grad_fn=<AddBackward0>)
# X = tensor(0.0586, requires_grad=True), f(x) = tensor(4.0655, grad_fn=<AddBackward0>)
# X = tensor(0.0574, requires_grad=True), f(x) = tensor(4.0640, grad_fn=<AddBackward0>)
# X = tensor(0.0562, requires_grad=True), f(x) = tensor(4.0625, grad_fn=<AddBackward0>)
# X = tensor(0.0549, requires_grad=True), f(x) = tensor(4.0610, grad_fn=<AddBackward0>)
# X = tensor(0.0537, requires_grad=True), f(x) = tensor(4.0595, grad_fn=<AddBackward0>)
# X = tensor(0.0525, requires_grad=True), f(x) = tensor(4.0580, grad_fn=<AddBackward0>)
# X = tensor(0.0513, requires_grad=True), f(x) = tensor(4.0565, grad_fn=<AddBackward0>)
# X = tensor(0.0501, requires_grad=True), f(x) = tensor(4.0551, grad_fn=<AddBackward0>)
# X = tensor(0.0489, requires_grad=True), f(x) = tensor(4.0537, grad_fn=<AddBackward0>)
# X = tensor(0.0477, requires_grad=True), f(x) = tensor(4.0522, grad_fn=<AddBackward0>)
# X = tensor(0.0465, requires_grad=True), f(x) = tensor(4.0508, grad_fn=<AddBackward0>)
# X = tensor(0.0453, requires_grad=True), f(x) = tensor(4.0494, grad_fn=<AddBackward0>)
# X = tensor(0.0441, requires_grad=True), f(x) = tensor(4.0480, grad_fn=<AddBackward0>)
# X = tensor(0.0429, requires_grad=True), f(x) = tensor(4.0466, grad_fn=<AddBackward0>)
# X = tensor(0.0418, requires_grad=True), f(x) = tensor(4.0453, grad_fn=<AddBackward0>)
# X = tensor(0.0406, requires_grad=True), f(x) = tensor(4.0439, grad_fn=<AddBackward0>)
# X = tensor(0.0394, requires_grad=True), f(x) = tensor(4.0426, grad_fn=<AddBackward0>)
# X = tensor(0.0383, requires_grad=True), f(x) = tensor(4.0412, grad_fn=<AddBackward0>)
# X = tensor(0.0371, requires_grad=True), f(x) = tensor(4.0399, grad_fn=<AddBackward0>)
# X = tensor(0.0360, requires_grad=True), f(x) = tensor(4.0386, grad_fn=<AddBackward0>)
# X = tensor(0.0348, requires_grad=True), f(x) = tensor(4.0373, grad_fn=<AddBackward0>)
# X = tensor(0.0337, requires_grad=True), f(x) = tensor(4.0360, grad_fn=<AddBackward0>)
# X = tensor(0.0326, requires_grad=True), f(x) = tensor(4.0347, grad_fn=<AddBackward0>)
# X = tensor(0.0314, requires_grad=True), f(x) = tensor(4.0334, grad_fn=<AddBackward0>)
# X = tensor(0.0303, requires_grad=True), f(x) = tensor(4.0322, grad_fn=<AddBackward0>)
# X = tensor(0.0292, requires_grad=True), f(x) = tensor(4.0309, grad_fn=<AddBackward0>)
# X = tensor(0.0281, requires_grad=True), f(x) = tensor(4.0297, grad_fn=<AddBackward0>)
# X = tensor(0.0270, requires_grad=True), f(x) = tensor(4.0284, grad_fn=<AddBackward0>)
# X = tensor(0.0259, requires_grad=True), f(x) = tensor(4.0272, grad_fn=<AddBackward0>)
# X = tensor(0.0248, requires_grad=True), f(x) = tensor(4.0260, grad_fn=<AddBackward0>)
# X = tensor(0.0237, requires_grad=True), f(x) = tensor(4.0248, grad_fn=<AddBackward0>)
# X = tensor(0.0226, requires_grad=True), f(x) = tensor(4.0236, grad_fn=<AddBackward0>)
# X = tensor(0.0215, requires_grad=True), f(x) = tensor(4.0224, grad_fn=<AddBackward0>)
# X = tensor(0.0204, requires_grad=True), f(x) = tensor(4.0212, grad_fn=<AddBackward0>)
# X = tensor(0.0193, requires_grad=True), f(x) = tensor(4.0200, grad_fn=<AddBackward0>)
# X = tensor(0.0182, requires_grad=True), f(x) = tensor(4.0189, grad_fn=<AddBackward0>)
# X = tensor(0.0172, requires_grad=True), f(x) = tensor(4.0177, grad_fn=<AddBackward0>)
# X = tensor(0.0161, requires_grad=True), f(x) = tensor(4.0166, grad_fn=<AddBackward0>)
# X = tensor(0.0150, requires_grad=True), f(x) = tensor(4.0155, grad_fn=<AddBackward0>)
# X = tensor(0.0140, requires_grad=True), f(x) = tensor(4.0143, grad_fn=<AddBackward0>)
# X = tensor(0.0129, requires_grad=True), f(x) = tensor(4.0132, grad_fn=<AddBackward0>)
# X = tensor(0.0118, requires_grad=True), f(x) = tensor(4.0121, grad_fn=<AddBackward0>)
# X = tensor(0.0108, requires_grad=True), f(x) = tensor(4.0110, grad_fn=<AddBackward0>)
# X = tensor(0.0098, requires_grad=True), f(x) = tensor(4.0099, grad_fn=<AddBackward0>)
# X = tensor(0.0087, requires_grad=True), f(x) = tensor(4.0089, grad_fn=<AddBackward0>)
# X = tensor(0.0077, requires_grad=True), f(x) = tensor(4.0078, grad_fn=<AddBackward0>)
# X = tensor(0.0067, requires_grad=True), f(x) = tensor(4.0067, grad_fn=<AddBackward0>)
# X = tensor(0.0056, requires_grad=True), f(x) = tensor(4.0057, grad_fn=<AddBackward0>)
# X = tensor(0.0046, requires_grad=True), f(x) = tensor(4.0046, grad_fn=<AddBackward0>)
# X = tensor(0.0036, requires_grad=True), f(x) = tensor(4.0036, grad_fn=<AddBackward0>)
# X = tensor(0.0026, requires_grad=True), f(x) = tensor(4.0026, grad_fn=<AddBackward0>)
# X = tensor(0.0016, requires_grad=True), f(x) = tensor(4.0016, grad_fn=<AddBackward0>)
# X = tensor(0.0006, requires_grad=True), f(x) = tensor(4.0006, grad_fn=<AddBackward0>)
# X = tensor(-0.0004, requires_grad=True), f(x) = tensor(3.9996, grad_fn=<AddBackward0>)
# X = tensor(-0.0014, requires_grad=True), f(x) = tensor(3.9986, grad_fn=<AddBackward0>)
# X = tensor(-0.0024, requires_grad=True), f(x) = tensor(3.9976, grad_fn=<AddBackward0>)
# X = tensor(-0.0034, requires_grad=True), f(x) = tensor(3.9966, grad_fn=<AddBackward0>)
# X = tensor(-0.0044, requires_grad=True), f(x) = tensor(3.9956, grad_fn=<AddBackward0>)
# X = tensor(-0.0054, requires_grad=True), f(x) = tensor(3.9947, grad_fn=<AddBackward0>)
# X = tensor(-0.0064, requires_grad=True), f(x) = tensor(3.9937, grad_fn=<AddBackward0>)
# X = tensor(-0.0074, requires_grad=True), f(x) = tensor(3.9928, grad_fn=<AddBackward0>)
# X = tensor(-0.0083, requires_grad=True), f(x) = tensor(3.9918, grad_fn=<AddBackward0>)
# X = tensor(-0.0093, requires_grad=True), f(x) = tensor(3.9909, grad_fn=<AddBackward0>)
# X = tensor(-0.0103, requires_grad=True), f(x) = tensor(3.9900, grad_fn=<AddBackward0>)
# X = tensor(-0.0112, requires_grad=True), f(x) = tensor(3.9890, grad_fn=<AddBackward0>)
# X = tensor(-0.0122, requires_grad=True), f(x) = tensor(3.9881, grad_fn=<AddBackward0>)
# X = tensor(-0.0131, requires_grad=True), f(x) = tensor(3.9872, grad_fn=<AddBackward0>)
# X = tensor(-0.0141, requires_grad=True), f(x) = tensor(3.9863, grad_fn=<AddBackward0>)
# X = tensor(-0.0150, requires_grad=True), f(x) = tensor(3.9854, grad_fn=<AddBackward0>)
# X = tensor(-0.0159, requires_grad=True), f(x) = tensor(3.9846, grad_fn=<AddBackward0>)
# X = tensor(-0.0169, requires_grad=True), f(x) = tensor(3.9837, grad_fn=<AddBackward0>)
# X = tensor(-0.0178, requires_grad=True), f(x) = tensor(3.9828, grad_fn=<AddBackward0>)
# X = tensor(-0.0187, requires_grad=True), f(x) = tensor(3.9820, grad_fn=<AddBackward0>)
# X = tensor(-0.0197, requires_grad=True), f(x) = tensor(3.9811, grad_fn=<AddBackward0>)
# X = tensor(-0.0206, requires_grad=True), f(x) = tensor(3.9803, grad_fn=<AddBackward0>)
# X = tensor(-0.0215, requires_grad=True), f(x) = tensor(3.9794, grad_fn=<AddBackward0>)
# X = tensor(-0.0224, requires_grad=True), f(x) = tensor(3.9786, grad_fn=<AddBackward0>)
# X = tensor(-0.0233, requires_grad=True), f(x) = tensor(3.9778, grad_fn=<AddBackward0>)
# X = tensor(-0.0242, requires_grad=True), f(x) = tensor(3.9769, grad_fn=<AddBackward0>)
# X = tensor(-0.0251, requires_grad=True), f(x) = tensor(3.9761, grad_fn=<AddBackward0>)
# X = tensor(-0.0260, requires_grad=True), f(x) = tensor(3.9753, grad_fn=<AddBackward0>)
# X = tensor(-0.0269, requires_grad=True), f(x) = tensor(3.9745, grad_fn=<AddBackward0>)
# X = tensor(-0.0278, requires_grad=True), f(x) = tensor(3.9737, grad_fn=<AddBackward0>)
# X = tensor(-0.0287, requires_grad=True), f(x) = tensor(3.9729, grad_fn=<AddBackward0>)
# X = tensor(-0.0296, requires_grad=True), f(x) = tensor(3.9721, grad_fn=<AddBackward0>)
# X = tensor(-0.0305, requires_grad=True), f(x) = tensor(3.9714, grad_fn=<AddBackward0>)
# X = tensor(-0.0314, requires_grad=True), f(x) = tensor(3.9706, grad_fn=<AddBackward0>)
# X = tensor(-0.0322, requires_grad=True), f(x) = tensor(3.9698, grad_fn=<AddBackward0>)
# X = tensor(-0.0331, requires_grad=True), f(x) = tensor(3.9691, grad_fn=<AddBackward0>)
# X = tensor(-0.0340, requires_grad=True), f(x) = tensor(3.9683, grad_fn=<AddBackward0>)
# X = tensor(-0.0348, requires_grad=True), f(x) = tensor(3.9676, grad_fn=<AddBackward0>)
# X = tensor(-0.0357, requires_grad=True), f(x) = tensor(3.9668, grad_fn=<AddBackward0>)
# X = tensor(-0.0366, requires_grad=True), f(x) = tensor(3.9661, grad_fn=<AddBackward0>)
# X = tensor(-0.0374, requires_grad=True), f(x) = tensor(3.9654, grad_fn=<AddBackward0>)
# X = tensor(-0.0383, requires_grad=True), f(x) = tensor(3.9647, grad_fn=<AddBackward0>)
# X = tensor(-0.0391, requires_grad=True), f(x) = tensor(3.9639, grad_fn=<AddBackward0>)
# X = tensor(-0.0400, requires_grad=True), f(x) = tensor(3.9632, grad_fn=<AddBackward0>)
# X = tensor(-0.0408, requires_grad=True), f(x) = tensor(3.9625, grad_fn=<AddBackward0>)
# X = tensor(-0.0416, requires_grad=True), f(x) = tensor(3.9618, grad_fn=<AddBackward0>)
# X = tensor(-0.0425, requires_grad=True), f(x) = tensor(3.9611, grad_fn=<AddBackward0>)
# X = tensor(-0.0433, requires_grad=True), f(x) = tensor(3.9605, grad_fn=<AddBackward0>)
# X = tensor(-0.0441, requires_grad=True), f(x) = tensor(3.9598, grad_fn=<AddBackward0>)
# X = tensor(-0.0449, requires_grad=True), f(x) = tensor(3.9591, grad_fn=<AddBackward0>)
# X = tensor(-0.0458, requires_grad=True), f(x) = tensor(3.9584, grad_fn=<AddBackward0>)
# X = tensor(-0.0466, requires_grad=True), f(x) = tensor(3.9578, grad_fn=<AddBackward0>)
# X = tensor(-0.0474, requires_grad=True), f(x) = tensor(3.9571, grad_fn=<AddBackward0>)
# X = tensor(-0.0482, requires_grad=True), f(x) = tensor(3.9564, grad_fn=<AddBackward0>)
# X = tensor(-0.0490, requires_grad=True), f(x) = tensor(3.9558, grad_fn=<AddBackward0>)
# X = tensor(-0.0498, requires_grad=True), f(x) = tensor(3.9551, grad_fn=<AddBackward0>)
# X = tensor(-0.0506, requires_grad=True), f(x) = tensor(3.9545, grad_fn=<AddBackward0>)
# X = tensor(-0.0514, requires_grad=True), f(x) = tensor(3.9539, grad_fn=<AddBackward0>)
# X = tensor(-0.0522, requires_grad=True), f(x) = tensor(3.9532, grad_fn=<AddBackward0>)
# X = tensor(-0.0530, requires_grad=True), f(x) = tensor(3.9526, grad_fn=<AddBackward0>)
# X = tensor(-0.0538, requires_grad=True), f(x) = tensor(3.9520, grad_fn=<AddBackward0>)
# X = tensor(-0.0546, requires_grad=True), f(x) = tensor(3.9514, grad_fn=<AddBackward0>)
# X = tensor(-0.0554, requires_grad=True), f(x) = tensor(3.9508, grad_fn=<AddBackward0>)
# X = tensor(-0.0561, requires_grad=True), f(x) = tensor(3.9502, grad_fn=<AddBackward0>)
# X = tensor(-0.0569, requires_grad=True), f(x) = tensor(3.9496, grad_fn=<AddBackward0>)
# X = tensor(-0.0577, requires_grad=True), f(x) = tensor(3.9490, grad_fn=<AddBackward0>)
# X = tensor(-0.0585, requires_grad=True), f(x) = tensor(3.9484, grad_fn=<AddBackward0>)
# X = tensor(-0.0592, requires_grad=True), f(x) = tensor(3.9478, grad_fn=<AddBackward0>)
# X = tensor(-0.0600, requires_grad=True), f(x) = tensor(3.9472, grad_fn=<AddBackward0>)
# X = tensor(-0.0607, requires_grad=True), f(x) = tensor(3.9466, grad_fn=<AddBackward0>)
# X = tensor(-0.0615, requires_grad=True), f(x) = tensor(3.9461, grad_fn=<AddBackward0>)
# X = tensor(-0.0623, requires_grad=True), f(x) = tensor(3.9455, grad_fn=<AddBackward0>)
# X = tensor(-0.0630, requires_grad=True), f(x) = tensor(3.9449, grad_fn=<AddBackward0>)
# X = tensor(-0.0638, requires_grad=True), f(x) = tensor(3.9444, grad_fn=<AddBackward0>)
# X = tensor(-0.0645, requires_grad=True), f(x) = tensor(3.9438, grad_fn=<AddBackward0>)
# X = tensor(-0.0652, requires_grad=True), f(x) = tensor(3.9433, grad_fn=<AddBackward0>)
# X = tensor(-0.0660, requires_grad=True), f(x) = tensor(3.9427, grad_fn=<AddBackward0>)
# X = tensor(-0.0667, requires_grad=True), f(x) = tensor(3.9422, grad_fn=<AddBackward0>)
# X = tensor(-0.0674, requires_grad=True), f(x) = tensor(3.9417, grad_fn=<AddBackward0>)
# X = tensor(-0.0682, requires_grad=True), f(x) = tensor(3.9411, grad_fn=<AddBackward0>)
# X = tensor(-0.0689, requires_grad=True), f(x) = tensor(3.9406, grad_fn=<AddBackward0>)
# X = tensor(-0.0696, requires_grad=True), f(x) = tensor(3.9401, grad_fn=<AddBackward0>)
# X = tensor(-0.0703, requires_grad=True), f(x) = tensor(3.9395, grad_fn=<AddBackward0>)
# X = tensor(-0.0711, requires_grad=True), f(x) = tensor(3.9390, grad_fn=<AddBackward0>)
# X = tensor(-0.0718, requires_grad=True), f(x) = tensor(3.9385, grad_fn=<AddBackward0>)
# X = tensor(-0.0725, requires_grad=True), f(x) = tensor(3.9380, grad_fn=<AddBackward0>)
# X = tensor(-0.0732, requires_grad=True), f(x) = tensor(3.9375, grad_fn=<AddBackward0>)
# X = tensor(-0.0739, requires_grad=True), f(x) = tensor(3.9370, grad_fn=<AddBackward0>)
# X = tensor(-0.0746, requires_grad=True), f(x) = tensor(3.9365, grad_fn=<AddBackward0>)
# X = tensor(-0.0753, requires_grad=True), f(x) = tensor(3.9360, grad_fn=<AddBackward0>)
# X = tensor(-0.0760, requires_grad=True), f(x) = tensor(3.9355, grad_fn=<AddBackward0>)
# X = tensor(-0.0767, requires_grad=True), f(x) = tensor(3.9351, grad_fn=<AddBackward0>)
# X = tensor(-0.0774, requires_grad=True), f(x) = tensor(3.9346, grad_fn=<AddBackward0>)
# X = tensor(-0.0781, requires_grad=True), f(x) = tensor(3.9341, grad_fn=<AddBackward0>)
# X = tensor(-0.0788, requires_grad=True), f(x) = tensor(3.9336, grad_fn=<AddBackward0>)
# X = tensor(-0.0795, requires_grad=True), f(x) = tensor(3.9332, grad_fn=<AddBackward0>)
# X = tensor(-0.0802, requires_grad=True), f(x) = tensor(3.9327, grad_fn=<AddBackward0>)
# X = tensor(-0.0808, requires_grad=True), f(x) = tensor(3.9322, grad_fn=<AddBackward0>)
# X = tensor(-0.0815, requires_grad=True), f(x) = tensor(3.9318, grad_fn=<AddBackward0>)
# X = tensor(-0.0822, requires_grad=True), f(x) = tensor(3.9313, grad_fn=<AddBackward0>)
# X = tensor(-0.0829, requires_grad=True), f(x) = tensor(3.9309, grad_fn=<AddBackward0>)
# X = tensor(-0.0835, requires_grad=True), f(x) = tensor(3.9304, grad_fn=<AddBackward0>)
# X = tensor(-0.0842, requires_grad=True), f(x) = tensor(3.9300, grad_fn=<AddBackward0>)
# X = tensor(-0.0849, requires_grad=True), f(x) = tensor(3.9295, grad_fn=<AddBackward0>)
# X = tensor(-0.0855, requires_grad=True), f(x) = tensor(3.9291, grad_fn=<AddBackward0>)
# X = tensor(-0.0862, requires_grad=True), f(x) = tensor(3.9287, grad_fn=<AddBackward0>)
# X = tensor(-0.0868, requires_grad=True), f(x) = tensor(3.9283, grad_fn=<AddBackward0>)
# X = tensor(-0.0875, requires_grad=True), f(x) = tensor(3.9278, grad_fn=<AddBackward0>)
# X = tensor(-0.0881, requires_grad=True), f(x) = tensor(3.9274, grad_fn=<AddBackward0>)
# X = tensor(-0.0888, requires_grad=True), f(x) = tensor(3.9270, grad_fn=<AddBackward0>)
# X = tensor(-0.0894, requires_grad=True), f(x) = tensor(3.9266, grad_fn=<AddBackward0>)
# X = tensor(-0.0901, requires_grad=True), f(x) = tensor(3.9262, grad_fn=<AddBackward0>)
# X = tensor(-0.0907, requires_grad=True), f(x) = tensor(3.9258, grad_fn=<AddBackward0>)
# X = tensor(-0.0913, requires_grad=True), f(x) = tensor(3.9253, grad_fn=<AddBackward0>)
# X = tensor(-0.0920, requires_grad=True), f(x) = tensor(3.9249, grad_fn=<AddBackward0>)
# X = tensor(-0.0926, requires_grad=True), f(x) = tensor(3.9245, grad_fn=<AddBackward0>)
# X = tensor(-0.0932, requires_grad=True), f(x) = tensor(3.9242, grad_fn=<AddBackward0>)
# X = tensor(-0.0939, requires_grad=True), f(x) = tensor(3.9238, grad_fn=<AddBackward0>)
# X = tensor(-0.0945, requires_grad=True), f(x) = tensor(3.9234, grad_fn=<AddBackward0>)
# X = tensor(-0.0951, requires_grad=True), f(x) = tensor(3.9230, grad_fn=<AddBackward0>)
# X = tensor(-0.0957, requires_grad=True), f(x) = tensor(3.9226, grad_fn=<AddBackward0>)
# X = tensor(-0.0963, requires_grad=True), f(x) = tensor(3.9222, grad_fn=<AddBackward0>)
# X = tensor(-0.0970, requires_grad=True), f(x) = tensor(3.9218, grad_fn=<AddBackward0>)
# X = tensor(-0.0976, requires_grad=True), f(x) = tensor(3.9215, grad_fn=<AddBackward0>)
# X = tensor(-0.0982, requires_grad=True), f(x) = tensor(3.9211, grad_fn=<AddBackward0>)
# X = tensor(-0.0988, requires_grad=True), f(x) = tensor(3.9207, grad_fn=<AddBackward0>)
# X = tensor(-0.0994, requires_grad=True), f(x) = tensor(3.9204, grad_fn=<AddBackward0>)
# X = tensor(-0.1000, requires_grad=True), f(x) = tensor(3.9200, grad_fn=<AddBackward0>)
# X = tensor(-0.1006, requires_grad=True), f(x) = tensor(3.9196, grad_fn=<AddBackward0>)
# X = tensor(-0.1012, requires_grad=True), f(x) = tensor(3.9193, grad_fn=<AddBackward0>)
# X = tensor(-0.1018, requires_grad=True), f(x) = tensor(3.9189, grad_fn=<AddBackward0>)
# X = tensor(-0.1024, requires_grad=True), f(x) = tensor(3.9186, grad_fn=<AddBackward0>)
# X = tensor(-0.1030, requires_grad=True), f(x) = tensor(3.9182, grad_fn=<AddBackward0>)
# X = tensor(-0.1036, requires_grad=True), f(x) = tensor(3.9179, grad_fn=<AddBackward0>)
# X = tensor(-0.1041, requires_grad=True), f(x) = tensor(3.9175, grad_fn=<AddBackward0>)
# X = tensor(-0.1047, requires_grad=True), f(x) = tensor(3.9172, grad_fn=<AddBackward0>)
# X = tensor(-0.1053, requires_grad=True), f(x) = tensor(3.9169, grad_fn=<AddBackward0>)
# X = tensor(-0.1059, requires_grad=True), f(x) = tensor(3.9165, grad_fn=<AddBackward0>)
# X = tensor(-0.1065, requires_grad=True), f(x) = tensor(3.9162, grad_fn=<AddBackward0>)
# X = tensor(-0.1070, requires_grad=True), f(x) = tensor(3.9159, grad_fn=<AddBackward0>)
# X = tensor(-0.1076, requires_grad=True), f(x) = tensor(3.9155, grad_fn=<AddBackward0>)
# X = tensor(-0.1082, requires_grad=True), f(x) = tensor(3.9152, grad_fn=<AddBackward0>)
# X = tensor(-0.1087, requires_grad=True), f(x) = tensor(3.9149, grad_fn=<AddBackward0>)
# X = tensor(-0.1093, requires_grad=True), f(x) = tensor(3.9146, grad_fn=<AddBackward0>)
# X = tensor(-0.1099, requires_grad=True), f(x) = tensor(3.9143, grad_fn=<AddBackward0>)
# X = tensor(-0.1104, requires_grad=True), f(x) = tensor(3.9140, grad_fn=<AddBackward0>)
# X = tensor(-0.1110, requires_grad=True), f(x) = tensor(3.9136, grad_fn=<AddBackward0>)
# X = tensor(-0.1116, requires_grad=True), f(x) = tensor(3.9133, grad_fn=<AddBackward0>)
# X = tensor(-0.1121, requires_grad=True), f(x) = tensor(3.9130, grad_fn=<AddBackward0>)
# X = tensor(-0.1127, requires_grad=True), f(x) = tensor(3.9127, grad_fn=<AddBackward0>)
# X = tensor(-0.1132, requires_grad=True), f(x) = tensor(3.9124, grad_fn=<AddBackward0>)
# X = tensor(-0.1138, requires_grad=True), f(x) = tensor(3.9121, grad_fn=<AddBackward0>)
# X = tensor(-0.1143, requires_grad=True), f(x) = tensor(3.9118, grad_fn=<AddBackward0>)
# X = tensor(-0.1148, requires_grad=True), f(x) = tensor(3.9115, grad_fn=<AddBackward0>)
# ...
# X = tensor(-0.2027, requires_grad=True), f(x) = tensor(3.8795, grad_fn=<AddBackward0>)
# X = tensor(-0.2029, requires_grad=True), f(x) = tensor(3.8794, grad_fn=<AddBackward0>)
# X = tensor(-0.2031, requires_grad=True), f(x) = tensor(3.8794, grad_fn=<AddBackward0>)
# X = tensor(-0.2033, requires_grad=True), f(x) = tensor(3.8794, grad_fn=<AddBackward0>)
# X = tensor(-0.2035, requires_grad=True), f(x) = tensor(3.8793, grad_fn=<AddBackward0>)
# X = tensor(-0.2036, requires_grad=True), f(x) = tensor(3.8793, grad_fn=<AddBackward0>)
# X = tensor(-0.2038, requires_grad=True), f(x) = tensor(3.8793, grad_fn=<AddBackward0>)
# X = tensor(-0.2040, requires_grad=True), f(x) = tensor(3.8792, grad_fn=<AddBackward0>)
# X = tensor(-0.2042, requires_grad=True), f(x) = tensor(3.8792, grad_fn=<AddBackward0>)
# X = tensor(-0.2044, requires_grad=True), f(x) = tensor(3.8792, grad_fn=<AddBackward0>)
# X = tensor(-0.2046, requires_grad=True), f(x) = tensor(3.8791, grad_fn=<AddBackward0>)
# X = tensor(-0.2047, requires_grad=True), f(x) = tensor(3.8791, grad_fn=<AddBackward0>)
# X = tensor(-0.2049, requires_grad=True), f(x) = tensor(3.8791, grad_fn=<AddBackward0>)
# X = tensor(-0.2051, requires_grad=True), f(x) = tensor(3.8790, grad_fn=<AddBackward0>)
# X = tensor(-0.2053, requires_grad=True), f(x) = tensor(3.8790, grad_fn=<AddBackward0>)
# X = tensor(-0.2055, requires_grad=True), f(x) = tensor(3.8790, grad_fn=<AddBackward0>)
# X = tensor(-0.2056, requires_grad=True), f(x) = tensor(3.8789, grad_fn=<AddBackward0>)
# X = tensor(-0.2058, requires_grad=True), f(x) = tensor(3.8789, grad_fn=<AddBackward0>)
# X = tensor(-0.2060, requires_grad=True), f(x) = tensor(3.8789, grad_fn=<AddBackward0>)
# X = tensor(-0.2062, requires_grad=True), f(x) = tensor(3.8788, grad_fn=<AddBackward0>)
# X = tensor(-0.2064, requires_grad=True), f(x) = tensor(3.8788, grad_fn=<AddBackward0>)
# X = tensor(-0.2065, requires_grad=True), f(x) = tensor(3.8788, grad_fn=<AddBackward0>)
# X = tensor(-0.2067, requires_grad=True), f(x) = tensor(3.8787, grad_fn=<AddBackward0>)
# X = tensor(-0.2069, requires_grad=True), f(x) = tensor(3.8787, grad_fn=<AddBackward0>)
# X = tensor(-0.2070, requires_grad=True), f(x) = tensor(3.8787, grad_fn=<AddBackward0>)
# X = tensor(-0.2072, requires_grad=True), f(x) = tensor(3.8787, grad_fn=<AddBackward0>)
# X = tensor(-0.2074, requires_grad=True), f(x) = tensor(3.8786, grad_fn=<AddBackward0>)
# X = tensor(-0.2076, requires_grad=True), f(x) = tensor(3.8786, grad_fn=<AddBackward0>)
# X = tensor(-0.2077, requires_grad=True), f(x) = tensor(3.8786, grad_fn=<AddBackward0>)
# X = tensor(-0.2079, requires_grad=True), f(x) = tensor(3.8785, grad_fn=<AddBackward0>)
# X = tensor(-0.2081, requires_grad=True), f(x) = tensor(3.8785, grad_fn=<AddBackward0>)
# X = tensor(-0.2082, requires_grad=True), f(x) = tensor(3.8785, grad_fn=<AddBackward0>)
# X = tensor(-0.2084, requires_grad=True), f(x) = tensor(3.8785, grad_fn=<AddBackward0>)
# X = tensor(-0.2086, requires_grad=True), f(x) = tensor(3.8784, grad_fn=<AddBackward0>)
# X = tensor(-0.2087, requires_grad=True), f(x) = tensor(3.8784, grad_fn=<AddBackward0>)
# X = tensor(-0.2089, requires_grad=True), f(x) = tensor(3.8784, grad_fn=<AddBackward0>)
# X = tensor(-0.2091, requires_grad=True), f(x) = tensor(3.8784, grad_fn=<AddBackward0>)
# X = tensor(-0.2092, requires_grad=True), f(x) = tensor(3.8783, grad_fn=<AddBackward0>)
# X = tensor(-0.2094, requires_grad=True), f(x) = tensor(3.8783, grad_fn=<AddBackward0>)
# X = tensor(-0.2096, requires_grad=True), f(x) = tensor(3.8783, grad_fn=<AddBackward0>)
# X = tensor(-0.2097, requires_grad=True), f(x) = tensor(3.8782, grad_fn=<AddBackward0>)
# X = tensor(-0.2099, requires_grad=True), f(x) = tensor(3.8782, grad_fn=<AddBackward0>)
# X = tensor(-0.2100, requires_grad=True), f(x) = tensor(3.8782, grad_fn=<AddBackward0>)
# X = tensor(-0.2102, requires_grad=True), f(x) = tensor(3.8782, grad_fn=<AddBackward0>)
# X = tensor(-0.2104, requires_grad=True), f(x) = tensor(3.8781, grad_fn=<AddBackward0>)
# X = tensor(-0.2105, requires_grad=True), f(x) = tensor(3.8781, grad_fn=<AddBackward0>)
# X = tensor(-0.2107, requires_grad=True), f(x) = tensor(3.8781, grad_fn=<AddBackward0>)
# X = tensor(-0.2108, requires_grad=True), f(x) = tensor(3.8781, grad_fn=<AddBackward0>)
# X = tensor(-0.2110, requires_grad=True), f(x) = tensor(3.8780, grad_fn=<AddBackward0>)
# X = tensor(-0.2111, requires_grad=True), f(x) = tensor(3.8780, grad_fn=<AddBackward0>)
# X = tensor(-0.2113, requires_grad=True), f(x) = tensor(3.8780, grad_fn=<AddBackward0>)
# X = tensor(-0.2115, requires_grad=True), f(x) = tensor(3.8780, grad_fn=<AddBackward0>)
# X = tensor(-0.2116, requires_grad=True), f(x) = tensor(3.8779, grad_fn=<AddBackward0>)
# X = tensor(-0.2118, requires_grad=True), f(x) = tensor(3.8779, grad_fn=<AddBackward0>)
# X = tensor(-0.2119, requires_grad=True), f(x) = tensor(3.8779, grad_fn=<AddBackward0>)
# X = tensor(-0.2121, requires_grad=True), f(x) = tensor(3.8779, grad_fn=<AddBackward0>)
# X = tensor(-0.2122, requires_grad=True), f(x) = tensor(3.8779, grad_fn=<AddBackward0>)
# X = tensor(-0.2124, requires_grad=True), f(x) = tensor(3.8778, grad_fn=<AddBackward0>)
# X = tensor(-0.2125, requires_grad=True), f(x) = tensor(3.8778, grad_fn=<AddBackward0>)
# X = tensor(-0.2127, requires_grad=True), f(x) = tensor(3.8778, grad_fn=<AddBackward0>)
# X = tensor(-0.2128, requires_grad=True), f(x) = tensor(3.8778, grad_fn=<AddBackward0>)
# X = tensor(-0.2130, requires_grad=True), f(x) = tensor(3.8777, grad_fn=<AddBackward0>)
# X = tensor(-0.2131, requires_grad=True), f(x) = tensor(3.8777, grad_fn=<AddBackward0>)
# X = tensor(-0.2133, requires_grad=True), f(x) = tensor(3.8777, grad_fn=<AddBackward0>)
# X = tensor(-0.2134, requires_grad=True), f(x) = tensor(3.8777, grad_fn=<AddBackward0>)
# X = tensor(-0.2136, requires_grad=True), f(x) = tensor(3.8777, grad_fn=<AddBackward0>)
# X = tensor(-0.2137, requires_grad=True), f(x) = tensor(3.8776, grad_fn=<AddBackward0>)
# X = tensor(-0.2138, requires_grad=True), f(x) = tensor(3.8776, grad_fn=<AddBackward0>)
# X = tensor(-0.2140, requires_grad=True), f(x) = tensor(3.8776, grad_fn=<AddBackward0>)
# X = tensor(-0.2141, requires_grad=True), f(x) = tensor(3.8776, grad_fn=<AddBackward0>)
# X = tensor(-0.2143, requires_grad=True), f(x) = tensor(3.8776, grad_fn=<AddBackward0>)
# X = tensor(-0.2144, requires_grad=True), f(x) = tensor(3.8775, grad_fn=<AddBackward0>)
# X = tensor(-0.2146, requires_grad=True), f(x) = tensor(3.8775, grad_fn=<AddBackward0>)
# X = tensor(-0.2147, requires_grad=True), f(x) = tensor(3.8775, grad_fn=<AddBackward0>)
# X = tensor(-0.2148, requires_grad=True), f(x) = tensor(3.8775, grad_fn=<AddBackward0>)
# X = tensor(-0.2150, requires_grad=True), f(x) = tensor(3.8775, grad_fn=<AddBackward0>)
# X = tensor(-0.2151, requires_grad=True), f(x) = tensor(3.8774, grad_fn=<AddBackward0>)
# X = tensor(-0.2153, requires_grad=True), f(x) = tensor(3.8774, grad_fn=<AddBackward0>)
# X = tensor(-0.2154, requires_grad=True), f(x) = tensor(3.8774, grad_fn=<AddBackward0>)
# X = tensor(-0.2155, requires_grad=True), f(x) = tensor(3.8774, grad_fn=<AddBackward0>)
# X = tensor(-0.2157, requires_grad=True), f(x) = tensor(3.8774, grad_fn=<AddBackward0>)
# X = tensor(-0.2158, requires_grad=True), f(x) = tensor(3.8773, grad_fn=<AddBackward0>)
# X = tensor(-0.2160, requires_grad=True), f(x) = tensor(3.8773, grad_fn=<AddBackward0>)
# X = tensor(-0.2161, requires_grad=True), f(x) = tensor(3.8773, grad_fn=<AddBackward0>)
# X = tensor(-0.2162, requires_grad=True), f(x) = tensor(3.8773, grad_fn=<AddBackward0>)
# X = tensor(-0.2164, requires_grad=True), f(x) = tensor(3.8773, grad_fn=<AddBackward0>)
# X = tensor(-0.2165, requires_grad=True), f(x) = tensor(3.8772, grad_fn=<AddBackward0>)
# X = tensor(-0.2166, requires_grad=True), f(x) = tensor(3.8772, grad_fn=<AddBackward0>)
# X = tensor(-0.2168, requires_grad=True), f(x) = tensor(3.8772, grad_fn=<AddBackward0>)
# X = tensor(-0.2169, requires_grad=True), f(x) = tensor(3.8772, grad_fn=<AddBackward0>)
# X = tensor(-0.2170, requires_grad=True), f(x) = tensor(3.8772, grad_fn=<AddBackward0>)
# X = tensor(-0.2172, requires_grad=True), f(x) = tensor(3.8772, grad_fn=<AddBackward0>)
# X = tensor(-0.2173, requires_grad=True), f(x) = tensor(3.8771, grad_fn=<AddBackward0>)
# X = tensor(-0.2174, requires_grad=True), f(x) = tensor(3.8771, grad_fn=<AddBackward0>)
# X = tensor(-0.2176, requires_grad=True), f(x) = tensor(3.8771, grad_fn=<AddBackward0>)
# X = tensor(-0.2177, requires_grad=True), f(x) = tensor(3.8771, grad_fn=<AddBackward0>)
# X = tensor(-0.2178, requires_grad=True), f(x) = tensor(3.8771, grad_fn=<AddBackward0>)
# X = tensor(-0.2179, requires_grad=True), f(x) = tensor(3.8771, grad_fn=<AddBackward0>)
# X = tensor(-0.2181, requires_grad=True), f(x) = tensor(3.8770, grad_fn=<AddBackward0>)
# X = tensor(-0.2182, requires_grad=True), f(x) = tensor(3.8770, grad_fn=<AddBackward0>)
# X = tensor(-0.2183, requires_grad=True), f(x) = tensor(3.8770, grad_fn=<AddBackward0>)
# X = tensor(-0.2185, requires_grad=True), f(x) = tensor(3.8770, grad_fn=<AddBackward0>)
# X = tensor(-0.2186, requires_grad=True), f(x) = tensor(3.8770, grad_fn=<AddBackward0>)
# X = tensor(-0.2187, requires_grad=True), f(x) = tensor(3.8770, grad_fn=<AddBackward0>)
# X = tensor(-0.2188, requires_grad=True), f(x) = tensor(3.8769, grad_fn=<AddBackward0>)
# X = tensor(-0.2190, requires_grad=True), f(x) = tensor(3.8769, grad_fn=<AddBackward0>)
# X = tensor(-0.2191, requires_grad=True), f(x) = tensor(3.8769, grad_fn=<AddBackward0>)
# X = tensor(-0.2192, requires_grad=True), f(x) = tensor(3.8769, grad_fn=<AddBackward0>)
# X = tensor(-0.2193, requires_grad=True), f(x) = tensor(3.8769, grad_fn=<AddBackward0>)
# X = tensor(-0.2194, requires_grad=True), f(x) = tensor(3.8769, grad_fn=<AddBackward0>)
# X = tensor(-0.2196, requires_grad=True), f(x) = tensor(3.8769, grad_fn=<AddBackward0>)
# X = tensor(-0.2197, requires_grad=True), f(x) = tensor(3.8768, grad_fn=<AddBackward0>)
# X = tensor(-0.2198, requires_grad=True), f(x) = tensor(3.8768, grad_fn=<AddBackward0>)
# X = tensor(-0.2199, requires_grad=True), f(x) = tensor(3.8768, grad_fn=<AddBackward0>)
# X = tensor(-0.2201, requires_grad=True), f(x) = tensor(3.8768, grad_fn=<AddBackward0>)
# X = tensor(-0.2202, requires_grad=True), f(x) = tensor(3.8768, grad_fn=<AddBackward0>)
# X = tensor(-0.2203, requires_grad=True), f(x) = tensor(3.8768, grad_fn=<AddBackward0>)
# X = tensor(-0.2204, requires_grad=True), f(x) = tensor(3.8768, grad_fn=<AddBackward0>)
# X = tensor(-0.2205, requires_grad=True), f(x) = tensor(3.8767, grad_fn=<AddBackward0>)
# X = tensor(-0.2206, requires_grad=True), f(x) = tensor(3.8767, grad_fn=<AddBackward0>)
# X = tensor(-0.2208, requires_grad=True), f(x) = tensor(3.8767, grad_fn=<AddBackward0>)
# X = tensor(-0.2209, requires_grad=True), f(x) = tensor(3.8767, grad_fn=<AddBackward0>)
# X = tensor(-0.2210, requires_grad=True), f(x) = tensor(3.8767, grad_fn=<AddBackward0>)
# X = tensor(-0.2211, requires_grad=True), f(x) = tensor(3.8767, grad_fn=<AddBackward0>)
# X = tensor(-0.2212, requires_grad=True), f(x) = tensor(3.8767, grad_fn=<AddBackward0>)
# X = tensor(-0.2213, requires_grad=True), f(x) = tensor(3.8766, grad_fn=<AddBackward0>)
# X = tensor(-0.2215, requires_grad=True), f(x) = tensor(3.8766, grad_fn=<AddBackward0>)
# X = tensor(-0.2216, requires_grad=True), f(x) = tensor(3.8766, grad_fn=<AddBackward0>)
# X = tensor(-0.2217, requires_grad=True), f(x) = tensor(3.8766, grad_fn=<AddBackward0>)
# X = tensor(-0.2218, requires_grad=True), f(x) = tensor(3.8766, grad_fn=<AddBackward0>)
# X = tensor(-0.2219, requires_grad=True), f(x) = tensor(3.8766, grad_fn=<AddBackward0>)
# X = tensor(-0.2220, requires_grad=True), f(x) = tensor(3.8766, grad_fn=<AddBackward0>)
# X = tensor(-0.2221, requires_grad=True), f(x) = tensor(3.8766, grad_fn=<AddBackward0>)
# X = tensor(-0.2222, requires_grad=True), f(x) = tensor(3.8765, grad_fn=<AddBackward0>)
# X = tensor(-0.2224, requires_grad=True), f(x) = tensor(3.8765, grad_fn=<AddBackward0>)
# X = tensor(-0.2225, requires_grad=True), f(x) = tensor(3.8765, grad_fn=<AddBackward0>)
# X = tensor(-0.2226, requires_grad=True), f(x) = tensor(3.8765, grad_fn=<AddBackward0>)
# X = tensor(-0.2227, requires_grad=True), f(x) = tensor(3.8765, grad_fn=<AddBackward0>)
# X = tensor(-0.2228, requires_grad=True), f(x) = tensor(3.8765, grad_fn=<AddBackward0>)
# X = tensor(-0.2229, requires_grad=True), f(x) = tensor(3.8765, grad_fn=<AddBackward0>)
# X = tensor(-0.2230, requires_grad=True), f(x) = tensor(3.8765, grad_fn=<AddBackward0>)
# X = tensor(-0.2231, requires_grad=True), f(x) = tensor(3.8764, grad_fn=<AddBackward0>)
# X = tensor(-0.2232, requires_grad=True), f(x) = tensor(3.8764, grad_fn=<AddBackward0>)
# X = tensor(-0.2233, requires_grad=True), f(x) = tensor(3.8764, grad_fn=<AddBackward0>)
# X = tensor(-0.2234, requires_grad=True), f(x) = tensor(3.8764, grad_fn=<AddBackward0>)
# X = tensor(-0.2236, requires_grad=True), f(x) = tensor(3.8764, grad_fn=<AddBackward0>)
# X = tensor(-0.2237, requires_grad=True), f(x) = tensor(3.8764, grad_fn=<AddBackward0>)
# X = tensor(-0.2238, requires_grad=True), f(x) = tensor(3.8764, grad_fn=<AddBackward0>)
# X = tensor(-0.2239, requires_grad=True), f(x) = tensor(3.8764, grad_fn=<AddBackward0>)
# X = tensor(-0.2240, requires_grad=True), f(x) = tensor(3.8764, grad_fn=<AddBackward0>)
# X = tensor(-0.2241, requires_grad=True), f(x) = tensor(3.8763, grad_fn=<AddBackward0>)
# X = tensor(-0.2242, requires_grad=True), f(x) = tensor(3.8763, grad_fn=<AddBackward0>)
# X = tensor(-0.2243, requires_grad=True), f(x) = tensor(3.8763, grad_fn=<AddBackward0>)
# X = tensor(-0.2244, requires_grad=True), f(x) = tensor(3.8763, grad_fn=<AddBackward0>)
# X = tensor(-0.2245, requires_grad=True), f(x) = tensor(3.8763, grad_fn=<AddBackward0>)
# X = tensor(-0.2246, requires_grad=True), f(x) = tensor(3.8763, grad_fn=<AddBackward0>)
# X = tensor(-0.2247, requires_grad=True), f(x) = tensor(3.8763, grad_fn=<AddBackward0>)
# X = tensor(-0.2248, requires_grad=True), f(x) = tensor(3.8763, grad_fn=<AddBackward0>)
# X = tensor(-0.2249, requires_grad=True), f(x) = tensor(3.8763, grad_fn=<AddBackward0>)
# X = tensor(-0.2250, requires_grad=True), f(x) = tensor(3.8763, grad_fn=<AddBackward0>)
# X = tensor(-0.2251, requires_grad=True), f(x) = tensor(3.8762, grad_fn=<AddBackward0>)
# X = tensor(-0.2252, requires_grad=True), f(x) = tensor(3.8762, grad_fn=<AddBackward0>)
# X = tensor(-0.2253, requires_grad=True), f(x) = tensor(3.8762, grad_fn=<AddBackward0>)
# X = tensor(-0.2254, requires_grad=True), f(x) = tensor(3.8762, grad_fn=<AddBackward0>)
# X = tensor(-0.2255, requires_grad=True), f(x) = tensor(3.8762, grad_fn=<AddBackward0>)
# X = tensor(-0.2256, requires_grad=True), f(x) = tensor(3.8762, grad_fn=<AddBackward0>)
# X = tensor(-0.2257, requires_grad=True), f(x) = tensor(3.8762, grad_fn=<AddBackward0>)
# X = tensor(-0.2258, requires_grad=True), f(x) = tensor(3.8762, grad_fn=<AddBackward0>)
# X = tensor(-0.2259, requires_grad=True), f(x) = tensor(3.8762, grad_fn=<AddBackward0>)
# X = tensor(-0.2260, requires_grad=True), f(x) = tensor(3.8762, grad_fn=<AddBackward0>)
# X = tensor(-0.2261, requires_grad=True), f(x) = tensor(3.8761, grad_fn=<AddBackward0>)
# X = tensor(-0.2262, requires_grad=True), f(x) = tensor(3.8761, grad_fn=<AddBackward0>)
# X = tensor(-0.2263, requires_grad=True), f(x) = tensor(3.8761, grad_fn=<AddBackward0>)
# X = tensor(-0.2264, requires_grad=True), f(x) = tensor(3.8761, grad_fn=<AddBackward0>)
# X = tensor(-0.2265, requires_grad=True), f(x) = tensor(3.8761, grad_fn=<AddBackward0>)
# X = tensor(-0.2265, requires_grad=True), f(x) = tensor(3.8761, grad_fn=<AddBackward0>)
# X = tensor(-0.2266, requires_grad=True), f(x) = tensor(3.8761, grad_fn=<AddBackward0>)
# X = tensor(-0.2267, requires_grad=True), f(x) = tensor(3.8761, grad_fn=<AddBackward0>)
# X = tensor(-0.2268, requires_grad=True), f(x) = tensor(3.8761, grad_fn=<AddBackward0>)
# X = tensor(-0.2269, requires_grad=True), f(x) = tensor(3.8761, grad_fn=<AddBackward0>)
# X = tensor(-0.2270, requires_grad=True), f(x) = tensor(3.8761, grad_fn=<AddBackward0>)
# X = tensor(-0.2271, requires_grad=True), f(x) = tensor(3.8760, grad_fn=<AddBackward0>)
# X = tensor(-0.2272, requires_grad=True), f(x) = tensor(3.8760, grad_fn=<AddBackward0>)

# %% [markdown]
# # c) Implementando un MLP en PyTorch para predicción del procentaje de grasa corporal
#
# Contamos con una base de datos [1] de 252 mediciones del porcentaje de grasa corporal de 252 personas diferentes, el cual puede ser estimado mediante otras características, como la edad, el peso, y mediciones en diferentes partes del cuerpo. A partir de estos datos se pretende desarrollar un sistema que permita predecir dicho porcentaje a partir de las características.
#
# [1]: Olson, R.S., La Cava, W., Orzechowski, P. et al. PMLB: a large benchmark suite for machine learning evaluation and comparison. BioData Mining 10, 36 (2017). https://epistasislab.github.io/pmlb/profile/560_bodyfat.html
#
# Antes de comenzar, vamos a instalar el paquete de Python que contiene la base de datos:

# %%
pip install pmlb
# Out:
# Collecting pmlb
#   Downloading pmlb-1.0.1.post3-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from pmlb) (2.0.3)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from pmlb) (2.31.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from pmlb) (6.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->pmlb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->pmlb) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->pmlb) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->pmlb) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->pmlb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->pmlb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->pmlb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->pmlb) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->pmlb) (1.16.0)
# Installing collected packages: pmlb
# Successfully installed pmlb-1.0.1.post3

# %% [markdown]
# Ahora vamos a generar un histograma de todas las mediciones del porcentaje con todos los datos disponibles:

# %%
import matplotlib.pyplot as plt
import numpy as np
from pmlb import fetch_data

# Importamos el dataset
body_fat = fetch_data('560_bodyfat')
body_fat.describe()

# Extraigo los datos (features) y los porcentajes (etiquetas a predecir)
data = body_fat.loc[:, body_fat.columns != 'target'].to_numpy()
percentages = body_fat.loc[:, body_fat.columns == 'target'].to_numpy()

data = data.astype(np.float32)
percentages = percentages.astype(np.float32)

print("Fila de ejemplo:")
print(list(body_fat.columns))
print(data[0,:])

# Dibujo un histograma del porcentaje de grasa corporal usando todos los datos
_ = plt.hist( percentages , 50, density=True, facecolor='g', alpha=0.75)
_ = plt.title("Porcentaje de grasa corporal")
# Out:
# Fila de ejemplo:
# ['Density', 'Age', 'Weight', 'Height', 'Neck', 'Chest', 'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps', 'Forearm', 'Wrist', 'target']
# [  1.0708  23.     154.25    67.75    36.2     93.1     85.2     94.5
#   59.      37.3     21.9     32.      27.4     17.1   ]

# %% [markdown]
# Particionamos los datos en entrenamiento y prueba usando la función `sklearn.model_selection.train_test_split`

# %%
 from sklearn.model_selection import train_test_split

 # Particiono los datos en entrenamiento y prueba usando el método de scikitlearn
 X_train, X_test, y_train, y_test = train_test_split( data , percentages , test_size=0.33, random_state=42)

# %% [markdown]
# Ahora implementaremos en PyTorch un Perceptrón multicapa que usaremos como regresor del porcentaje de grasa corporal (ejemplo basado en el curso de [RPI](https://rpi.analyticsdojo.com/)).
#
# El perceptrón deberá contar con 3 capas:
# - Las dos primeras con 200 neuronas, y deberán usar la función de activación ReLU.
# - La última con una única neurona cuya salida sea un valor escalar que corresponda al porcentaje de grasa corporal estimado de la persona, que no deberá utilizar ninguna función de activación.
#
# Algunas clases de PyTorch que resultarán útiles para implementar el modelo, son:
# - `torch.nn.Linear`: Implementa una capa totalmente conectada. Es necesario especificarle el número de parámetros de entrada y de salida.
# - `torch.nn.functional.relu`: Implementa la función de activación ReLU.
#
# Además, utilizaremos el optimizador `torch.optim.Adam` y la función de pérdida `torch.nn.MSELoss` (error cuadrático medio).

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

# Tamaño del batch de entrenamiento
batch_size = 32

# Tasa de aprendizaje inicial para el gradiente descendente
learning_rate = 1e-3

class Net(torch.nn.Module):
    def __init__(self, input_features, size_hidden, n_output):
        super(Net, self).__init__()
        self.hidden1 = nn.Linear(input_features, size_hidden)
        self.hidden2 = nn.Linear(size_hidden,size_hidden)
        self.out = nn.Linear(size_hidden,n_output)
    def forward(self, x):
        x = F.relu(self.hidden1(x))
        x = F.relu(self.hidden2(x))
        x = self.out(x)
        return x

# Definimos el modelo del perceptrón
net = Net(14,200,1)

# Construimos el optimizador, y le indicamos que los parámetros a optimizar
# son los del modelo definido: net.parameters()

optimizer = torch.optim.Adam( net.parameters() , lr=learning_rate)

# Definimos también la función de pérdida a utilizar
criterion = nn.MSELoss()

# Creamos el objeto dataset que empaqueta los array de numpy para que puedan
# ser leidos por PyTorch
dataset = TensorDataset(torch.from_numpy(X_train).clone(), torch.from_numpy(y_train).clone())

# Creamos un loader iterable indicandole que debe leer los datos a partir de
# del dataset creado en el paso anterior. Este objeto puede ser iterado
# y nos devuelve de a un batch (x, y).
loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)

# Número de épocas
num_epochs = 5000

# Lista en la que iremos guardando el valor de la función de pérdida en cada
# etapa de entrenamiento
loss_list = []

# Bucle de entrenamiento
for i in range(num_epochs):

    total_loss = 0.0
    for x, y in loader:
        # Seteo en cero los gradientes de los parámetros a optimizar
        optimizer.zero_grad()

        # Realizo la pasada forward por la red
        prediccion = net(x)

        loss = criterion(prediccion,y)
        # Realizo la pasada backward por la red
        loss.backward()

        # Actualizo los pesos de la red con el optimizador
        optimizer.step()

        # Me guardo el valor actual de la función de pérdida para luego graficarlo
        loss_list.append(loss.data.item())

        # Acumulo la loss del minibatch
        total_loss += loss.item() * y.size(0)

    # Normalizo la loss total
    total_loss/= len(loader.dataset)

    # Muestro el valor de la función de pérdida cada 100 iteraciones
    if i > 0 and i % 100 == 0:
        print('Epoch %d, loss = %g' % (i, total_loss))

# Muestro la lista que contiene los valores de la función de pérdida
# y una versión suavizada (rojo) para observar la tendencia
plt.figure()
loss_np_array = np.array(loss_list)
plt.plot(loss_np_array, alpha = 0.3)
N = 60
running_avg_loss = np.convolve(loss_np_array, np.ones((N,))/N, mode='valid')
plt.plot(running_avg_loss, color='red')
plt.title("Función de pérdida durante el entrenamiento")
# Out:
# Epoch 100, loss = 19.6257
# Epoch 200, loss = 20.318
# Epoch 300, loss = 16.5554
# Epoch 400, loss = 16.5037
# Epoch 500, loss = 13.1676
# Epoch 600, loss = 13.8671
# Epoch 700, loss = 11.1032
# Epoch 800, loss = 12.4425
# Epoch 900, loss = 9.50754
# Epoch 1000, loss = 14.0573
# Epoch 1100, loss = 7.83502
# Epoch 1200, loss = 6.81255
# Epoch 1300, loss = 7.02109
# Epoch 1400, loss = 5.58506
# Epoch 1500, loss = 6.25909
# Epoch 1600, loss = 3.74034
# Epoch 1700, loss = 3.48211
# Epoch 1800, loss = 2.23144
# Epoch 1900, loss = 1.48668
# Epoch 2000, loss = 3.90167
# Epoch 2100, loss = 1.94946
# Epoch 2200, loss = 1.77309
# Epoch 2300, loss = 0.878816
# Epoch 2400, loss = 3.49899
# Epoch 2500, loss = 2.03719
# Epoch 2600, loss = 1.2838
# Epoch 2700, loss = 1.3657
# Epoch 2800, loss = 1.09529
# Epoch 2900, loss = 1.06825
# Epoch 3000, loss = 0.978224
# Epoch 3100, loss = 0.959258
# Epoch 3200, loss = 1.76081
# Epoch 3300, loss = 0.360951
# Epoch 3400, loss = 1.66001
# Epoch 3500, loss = 0.165514
# Epoch 3600, loss = 4.64898
# Epoch 3700, loss = 0.620624
# Epoch 3800, loss = 0.290984
# Epoch 3900, loss = 0.759187
# Epoch 4000, loss = 0.304087
# Epoch 4100, loss = 2.14322
# Epoch 4200, loss = 0.255397
# Epoch 4300, loss = 0.377122
# Epoch 4400, loss = 0.665523
# Epoch 4500, loss = 0.202427
# Epoch 4600, loss = 0.292194
# Epoch 4700, loss = 0.743382
# Epoch 4800, loss = 0.138979
# Epoch 4900, loss = 1.51929
# Text(0.5, 1.0, 'Función de pérdida durante el entrenamiento')

# %%
from sklearn.linear_model import LinearRegression
from numpy.linalg import norm

# Definimos un método para mostrar las predicciones como un scatter plot
# y graficamos la recta de regresión para esos datos.
def plotScatter(x_data, y_data, title, fit_line=True):
  plt.figure()

  plt.plot(x_data, y_data, '+')
  plt.xlabel('Valor real')
  plt.ylabel('Predicción')
  plt.title(title)

  if fit_line:
    X, Y = x_data.reshape(-1,1), y_data.reshape(-1,1)
    plt.plot( X, LinearRegression().fit(X, Y).predict(X) )

# Dibujamos el ground truth vs las predicciones en los datos de entrenamiento
py = net(torch.FloatTensor(X_train))
y_pred_train = py.cpu().detach().numpy()
plotScatter(y_train, y_pred_train, "Training data")

# Dibujamos el ground truth vs las predicciones en los datos de test
py = net(torch.FloatTensor(X_test))
y_pred_test = py.cpu().detach().numpy()
plotScatter(y_test, y_pred_test, "Test data")

print ("MSE medio en training: " + str(((y_train - y_pred_train)**2).mean()))
print ("MSE medio en test: " + str(((y_test - y_pred_test)**2).mean()))
# Out:
# MSE medio en training: 0.31562164
# MSE medio en test: 33.062263

# %% [markdown]
# # Entregable
# 1. Encontrar el mínimo de la función *f* definida en el apartado b). Para ello, deberán encontrar primero la derivada *f'(x)* de forma analítica, y utilizarla para computar el mínimo de la función. Posteriormente, deberán corrobarar que el valor coincida con el que obtuvieron optimizando la función con gradiente descendiente.
#
# 2. Compara el rendimiento de 3 perceptrones multicapa que varíen en la cantidad de neuronas en sus capas intermedia. Probar colocando 2, 10 y 200 neuronas en dichas capas, al entrenar los perceptrones durante 5000 épocas. Mostrar los resultados utilizando:
#
# * los gráficos de dispersión con la recta de regresión
# * el error medio en los datos de entrenamiento y test
#
#   Analizar la relación entre dichos resultados y la cantidad de neuronas que posee el perceptrón.

# %% [markdown]
# **Ejercicio 1:**
# La derivada  analítica de $$f(x) = 2x^2 + x + 4$$ es $$\frac{df}{dx} = 4x + 1$$
#
# Luego, el mínimo se alcanza igualando $\frac{df}{dx}$ a cero. Así, obtenemos que
# $x = -\frac{1}{4}$. Como la segunda derivada es positiva, es efectivamente el mínimo, siendo además el mismo valor obtenido al optimizar la función con gradiente descendiente.

# %%
def f(x):
  return 2*(x**2) + x + 4

def df(x):
  return 4*x + 1

# %%
def red_fit(neuronas,epocas):

  net = Net(14,neuronas,1)
  optimizer = torch.optim.Adam( net.parameters() , lr=learning_rate)

# Definimos también la función de pérdida a utilizar
  criterion = nn.MSELoss()

# Creamos el objeto dataset que empaqueta los array de numpy para que puedan
# ser leidos por PyTorch
  dataset = TensorDataset(torch.from_numpy(X_train).clone(), torch.from_numpy(y_train).clone())

# Creamos un loader iterable indicandole que debe leer los datos a partir de
# del dataset creado en el paso anterior. Este objeto puede ser iterado
# y nos devuelve de a un batch (x, y).
  loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)

# Número de épocas
  num_epochs = 5000

# Lista en la que iremos guardando el valor de la función de pérdida en cada
# etapa de entrenamiento
  loss_list = []

# Bucle de entrenamiento
  for i in range(epocas):

    total_loss = 0.0
    for x, y in loader:
        # Seteo en cero los gradientes de los parámetros a optimizar
        optimizer.zero_grad()

        # Realizo la pasada forward por la red
        prediccion = net(x)

        loss = criterion(prediccion,y)
        # Realizo la pasada backward por la red
        loss.backward()

        # Actualizo los pesos de la red con el optimizador
        optimizer.step()

        # Me guardo el valor actual de la función de pérdida para luego graficarlo
        loss_list.append(loss.data.item())

        # Acumulo la loss del minibatch
        total_loss += loss.item() * y.size(0)

    # Normalizo la loss total
    total_loss/= len(loader.dataset)

  return loss_list,net

# %%
def loss_graph(loss_list):
  plt.figure()
  loss_np_array = np.array(loss_list)
  plt.plot(loss_np_array, alpha = 0.3)
  N = 60
  running_avg_loss = np.convolve(loss_np_array, np.ones((N,))/N, mode='valid')
  plt.plot(running_avg_loss, color='red')
  plt.title("Función de pérdida durante el entrenamiento")

# %%
loss_list_2, net_2 = red_fit(2,5000)
loss_list_10, net_10 = red_fit(10,5000)

graph_ll2 = loss_graph(loss_list_2)
graph_ll10 = loss_graph(loss_list_10)

# %%
py = net_2(torch.FloatTensor(X_train))
y_pred_train = py.cpu().detach().numpy()
plotScatter(y_train, y_pred_train, "Training data")

py = net_2(torch.FloatTensor(X_test))
y_pred_test = py.cpu().detach().numpy()
plotScatter(y_test, y_pred_test, "Test data")

print ("MSE medio en training: " + str(((y_train - y_pred_train)**2).mean()))
print ("MSE medio en test: " + str(((y_test - y_pred_test)**2).mean()))
# Out:
# MSE medio en training: 17.9144
# MSE medio en test: 21.590036

# %%
py = net_10(torch.FloatTensor(X_train))
y_pred_train = py.cpu().detach().numpy()
plotScatter(y_train, y_pred_train, "Training data")

py = net_10(torch.FloatTensor(X_test))
y_pred_test = py.cpu().detach().numpy()
plotScatter(y_test, y_pred_test, "Test data")

print ("MSE medio en training: " + str(((y_train - y_pred_train)**2).mean()))
print ("MSE medio en test: " + str(((y_test - y_pred_test)**2).mean()))
# Out:
# MSE medio en training: 14.466162
# MSE medio en test: 23.081017

# %% [markdown]
# En la red entrenada con capas de 200 neuronas se observa un MSE muy bajo en el conjunto de entrenamiento y un MSE muy distinto en el conjunto de evaluación. Los MSE de las redes entrenadas con 2 y 10 neuronas por capa no son tan bajos como en la primera red y son similares entre sí pero mejoran el MSE en el conjunto de evaluación. Esto indica un sobreajuste a los datos de entrenamiento de la primera red.
# La red con 2 neuronas por capa debió ser entrenada varias veces para encontrar un buen óptimo en el conjunto de entrenamiento.
